# %%
from langchain.chat_models import init_chat_model
from pdfminer.high_level import extract_text
from typing import Optional, List, Dict
from typing_extensions import Annotated, TypedDict
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import PydanticOutputParser
from langchain_core.tools import tool
from langchain_core.messages import BaseMessage, SystemMessage, HumanMessage, ToolMessage
#from langchain_community.llms import IpexLLM

import torch

import pandas as pd
import getpass
import pdf2doi
import os

# %%
from mistralai import Mistral
from dotenv import load_dotenv
import datauri

# %%
class PaperInfo(TypedDict):
    title: Annotated[str, ..., 'Title of the research paper']
    author: Annotated[str, ..., 'Authors of the paper in (Name) et al. format']
    id: Annotated[str, ..., 'DOI or arXiv ID']
    data: Annotated[List[str], ..., 'Data used']
    code_link: Annotated[str, 'None provided', 'Link to code (Github, etc)']
    packages_used: Annotated[List[str], 'None Provided', 'Packages or libraries used.']
    task: Annotated[str, ..., 'Task performed in paper (e.g. flare prediction, CME detection, etc.)']
    field: Annotated[str, ...,'What branch of Space Science/Solar Physics e.g. solar flares, CME, solar wind, etc.']
    abstract: Annotated[str, ..., 'Summary of abstract']
    models: Annotated[List[str], ..., 'Model architecture(s) used e.g. CNN, ResNet, pix2pix, GAN, etc.']
    hybrid_model: Annotated[bool, ..., 'Whether hybrid model architectures were used.']
    multimodal: Annotated[List[str], 'N/A', 'Type of multimodal models used, if any.']
    baselines: Annotated[List[str], 'N/A', 'Baseline models or papers used, along with citations in the format: baseline (author, year).']
    preprocessing: Annotated[List[str], ..., 'Preprocessing steps taken']
    citations: Annotated[List[str], ..., 'Citations']
    approach_used: Annotated[List[str], ..., 'Approach(es) used']
    methodology: Annotated[str, ..., 'Summary of methodology']
    metrics: Annotated[List[Dict[str, float]], ..., 'Metrics used for evaluation and the scores obtained']
    limitations: Annotated[List[str], ..., 'Limitations of the research']
    strengths: Annotated[str, ..., 'Key strengths']
    weaknesses: Annotated[str, ..., 'Key weaknesses']
    reproducibility: Annotated[float, ..., 'From 0-5, based on the completeness of the method, code and data, how reproducible is the paper?']
    impact: Annotated[float, ..., 'From 0-10, how impactful is this paper based on current trends?']
    reuse_potential: Annotated[List[str], ..., 'Notes on potential for reuse ("None" if no potential)']

# %%
papers_df = pd.read_csv('../listup.csv')
papers_df['file_name'] = list(map(lambda name: name.split('.pdf')[0].split(' - ')[1], papers_df['file_name']))
papers = []

for file, content in zip(papers_df['file_name'], papers_df['content']):
    papers.append({'file_name': file, 'content': content})

# %%
llm = init_chat_model('mistral-large-latest', model_provider='mistralai')
structured_llm = llm.with_structured_output(PaperInfo)

# %%
embeddings = MistralAIEmbeddings(
    model='mistral-embed',
    api_key=os.environ['MISTRAL_API_KEY']
)
# Out:
# /data/dania.moriazi01/anaconda3/envs/space/lib/python3.11/site-packages/langchain_mistralai/embeddings.py:186: UserWarning: Could not download mistral tokenizer from Huggingface for calculating batch sizes. Set a Huggingface token via the HF_TOKEN environment variable to download the real tokenizer. Falling back to a dummy tokenizer that uses `len()`.
#   warnings.warn(

# %%
load_dotenv()
client = Mistral(api_key=os.environ['MISTRAL_API_KEY'])

# %%
def upload_pdf(file):
    pdf = client.files.upload(
        file={
            'file_name': file,
            'content': open(f'{file}', 'rb')
        },
        purpose='ocr'
    )

    signed_url = client.files.get_signed_url(file_id=pdf.id)
    return signed_url.url

# %%
def extract_pdf(file):
    ocr_response = client.ocr.process(
        model='mistral-ocr-latest',
        document={
            'type': 'document_url',
            'document_url': upload_pdf(file)
        },
        include_image_base64=True
    )

    return ocr_response

# %%
prompt = ChatPromptTemplate.from_messages(
    [
        ('system', "Extract information from the following research paper."),
        ('human', '{paper}')    
    ]
)

# %%
process_chain = prompt | structured_llm

# %%
data = []
for paper in papers:
    data.append(process_chain.invoke({'paper': paper['content']}))

# %%
for i in range(len(data)):
    data[i]['metrics_list'] = data[i]['metrics'].copy()
    data[i]['metrics'] = []
    data[i]['scores'] = []
    for j in range(len(data[i]['metrics_list'])):
        for key, value in data[i]['metrics_list'][j].items():
            data[i]['metrics'].append(key)
            data[i]['scores'].append(value)

# %%
data
# Out:
# [{'title': 'Generation of Modern Satellite Data from Galileo Sunspot Drawings in 1612 by Deep Learning',
#   'author': 'Lee et al.',
#   'id': '10.3847/1538-4357/abd498',
#   'data': ['Mount Wilson Observatory (MWO) sunspot drawings (2011-2015)',
#    'SDO/HMI line-of-sight magnetograms (2011-2015)',
#    'SDO/AIA seven wavelength images (94, 131, 171, 193, 211, 304, and 335 Å) (2011-2015)',
#    'Galileo sunspot drawings (1612 June 2 to July 8)'],
#   'code_link': 'None provided',
#   'packages_used': ['NumPy', 'Keras', 'TensorFlow', 'SunPy'],
#   'task': 'Generation of modern satellite-like magnetograms and EUV images from historical sunspot drawings',
#   'field': 'Solar Physics',
#   'keywords': 'deep learning, generative adversarial networks (GANs), pix2pix, sunspot drawings, historical data, solar magnetograms, EUV images, solar activity, image-to-image translation, solar cycle',
#   'abstract': 'This study uses deep learning to generate modern satellite-like magnetograms and EUV images from historical sunspot drawings by Galileo (1612) and Mount Wilson Observatory (2011-2015). A pix2pix model, based on conditional generative adversarial networks (cGANs), is trained on pairs of sunspot drawings and corresponding SDO/HMI magnetograms or SDO/AIA EUV images. The generated images are evaluated for their consistency with real satellite data, showing strong correlations in magnetic flux and EUV intensity. The model successfully reproduces bipolar magnetic structures and EUV brightness of active regions, offering potential insights into long-term solar activity and irradiance variations.',
#   'models': ['pix2pix (conditional GAN)'],
#   'hybrid_model': False,
#   'multimodal': ['N/A'],
#   'baselines': ['N/A'],
#   'preprocessing': ['Alignment of sunspot drawings with SDO images',
#    'Manual removal of letters and lines (excluding sunspots)',
#    'Conversion to 8-bit images (255 for solar disk, 0 for umbra, penumbra, and outside disk)',
#    'Calibration, rotation, and centering of SDO/HMI and AIA images',
#    'Division of AIA image data by exposure time for homogeneous exposure (DN s⁻¹)',
#    'Application of degrading factors to AIA images for instrument degradation correction',
#    'Coalignment and downscaling of images to 512x512 pixels',
#    'Exclusion of poor-quality images (e.g., noisy, incorrect headers, eclipses)',
#    'Selection of SDO images observed within ±36 minutes of sunspot drawing times'],
#   'citations': ['Isola et al. (2016)',
#    'Goodfellow et al. (2014)',
#    'Mirza & Osindero (2014)',
#    'Radford et al. (2015)',
#    'Hale & Nicholson (1925)',
#    'Boerner et al. (2012)',
#    'Liu et al. (2012)',
#    'Vokhmyanin & Zolotova (2018)',
#    'Galilei et al. (1613)',
#    'Kim et al. (2019)'],
#   'approach_used': ['Image-to-image translation using pix2pix (cGAN)',
#    'Training on paired sunspot drawings and SDO magnetograms/EUV images',
#    'Evaluation using correlation coefficients (CC) and normalized RMS error for magnetic flux and EUV intensity',
#    'Application to historical Galileo sunspot drawings for generating modern satellite-like images'],
#   'methodology': "The study employs a pix2pix model, a type of conditional GAN, to translate historical sunspot drawings into modern satellite-like magnetograms and EUV images. The model is trained on paired datasets of MWO sunspot drawings and corresponding SDO/HMI magnetograms or SDO/AIA EUV images from 2011-2015 (excluding June and December for evaluation). Preprocessing includes alignment, noise removal, and normalization of images. The generator network creates target-like images, while the discriminator distinguishes between real and generated pairs. The best model is selected based on the highest mean correlation coefficient (CC) for the evaluation dataset. The trained model is then applied to Galileo's sunspot drawings (1612) to generate HMI-like magnetograms and AIA-like EUV images, which are analyzed for magnetic flux and EUV intensity trends.",
#   'metrics': ['Correlation Coefficient (CC) for TUMF (Magnetograms)',
#    'Correlation Coefficient (CC) for 94 Å',
#    'Correlation Coefficient (CC) for 131 Å',
#    'Correlation Coefficient (CC) for 171 Å',
#    'Correlation Coefficient (CC) for 193 Å',
#    'Correlation Coefficient (CC) for 211 Å',
#    'Correlation Coefficient (CC) for 304 Å',
#    'Correlation Coefficient (CC) for 335 Å',
#    'Normalized RMS Error (TUMF and CR)'],
#   'limitations': ['The model struggles to reproduce detailed structures like filaments and coronal holes, as sunspot drawings lack such information.',
#    'The model assumes polarity patterns based on the 24th solar cycle and may not generalize to odd cycles without retraining.',
#    'Generated images slightly underestimate magnetic flux and EUV intensity due to limitations in capturing quiet regions and coronal structures.',
#    "The model's effectiveness is limited by the quality and clarity of historical sunspot drawings."],
#   'reproducibility': 4,
#   'strengths': 'The study demonstrates a novel application of deep learning to bridge historical and modern solar data, enabling the generation of satellite-like images from centuries-old sunspot drawings. The pix2pix model effectively captures bipolar magnetic structures and EUV brightness, with strong correlations in magnetic flux and intensity. This approach offers significant potential for long-term solar activity studies, particularly in estimating historical solar irradiance and understanding solar cycles.',
#   'weaknesses': "The model's reliance on sunspot drawings limits its ability to reproduce detailed coronal structures, which may affect the accuracy of generated EUV images. Additionally, the assumption of polarity patterns based on a single solar cycle may not hold for other cycles, requiring further validation. The lack of publicly available code reduces reproducibility, and the model's performance is constrained by the quality of historical data.",
#   'metrics_list': [{'Correlation Coefficient (CC) for TUMF (Magnetograms)': 0.82},
#    {'Correlation Coefficient (CC) for 94 Å': 0.74},
#    {'Correlation Coefficient (CC) for 131 Å': 0.75},
#    {'Correlation Coefficient (CC) for 171 Å': 0.56},
#    {'Correlation Coefficient (CC) for 193 Å': 0.65},
#    {'Correlation Coefficient (CC) for 211 Å': 0.67},
#    {'Correlation Coefficient (CC) for 304 Å': 0.7},
#    {'Correlation Coefficient (CC) for 335 Å': 0.76},
#    {'Normalized RMS Error (TUMF and CR)': 0.37}],
#   'scores': [0.82, 0.74, 0.75, 0.56, 0.65, 0.67, 0.7, 0.76, 0.37]},
#  {'title': 'Visual Explanation of a Deep Learning Solar Flare Forecast Model and Its Relationship to Physical Parameters',
#   'author': 'Yi et al.',
#   'id': '10.3847/2041-8213/abeb70',
#   'data': ['Solar and Heliospheric Observatory (SOHO)/Michelson Doppler Imager (MDI) magnetograms',
#    'Solar Dynamics Observatory (SDO)/Helioseismic and Magnetic Imager (HMI) magnetograms',
#    'Space-weather HMI Active Region Patch (SHARP) parameters',
#    'Geostationary Operational Environmental Satellite (GOES) X-ray flare data'],
#   'code_link': 'None provided',
#   'packages_used': ['PyTorch', 'NumPy', 'Matplotlib'],
#   'task': 'Solar flare prediction',
#   'field': 'Solar flares',
#   'keywords': 'deep learning, solar flare prediction, CNN, Grad-CAM, guided backpropagation, SHARP parameters, polarity inversion line (PIL), visual explanation',
#   'abstract': 'This study presents a visual explanation of a deep learning-based solar flare forecast model and its relationship to physical parameters of solar active regions (ARs). The model, based on a Convolutional Neural Network (CNN), predicts the daily occurrence of C-, M-, and X-class flares using full-disk magnetograms from SOHO/MDI and SDO/HMI, along with SHARP parameters and GOES X-ray flare data. The model is interpreted using CNN attribution methods such as guided backpropagation and Gradient-weighted Class Activation Mapping (Grad-CAM). Key findings include the importance of the polarity inversion line (PIL) for flare prediction and the correlation of Grad-CAM values with flare occurrence rates and SHARP parameters.',
#   'models': ['CNN with dense connections'],
#   'hybrid_model': False,
#   'multimodal': [],
#   'preprocessing': ['Resizing magnetograms to 512x512 resolution',
#    'Conversion of magnetograms to JPG format',
#    'Block averaging for resizing to 256x256 resolution for correlation analysis',
#    'Cubic interpolation for transferability analysis between MDI and HMI data'],
#   'citations': ['Priest & Forbes (2002)',
#    'Shibata & Magara (2011)',
#    'Schrijver (2007, 2016)',
#    'Sadykov & Kosovichev (2017)',
#    'Bobra et al. (2014)',
#    'Huang et al. (2018)',
#    'Nishizuka et al. (2018)',
#    'Park et al. (2018)',
#    'Chen et al. (2019)',
#    'Liu et al. (2019)',
#    'Li et al. (2020)'],
#   'approach_used': ['CNN-based flare prediction',
#    'Attribution methods (guided backpropagation and Grad-CAM) for model interpretation',
#    'Comparison of model predictions with SHARP physical parameters'],
#   'methodology': "The study involves training a CNN model on full-disk magnetogram data to predict solar flare occurrences. The model's predictions are interpreted using guided backpropagation and Grad-CAM to identify important regions in the input magnetograms. The relationship between these regions and physical parameters (SHARP) is analyzed to understand the model's decision-making process. The model is evaluated using metrics such as True Skill Statistics (TSS), Accuracy (ACC), Heidke Skill Score (HSS), and Appleman Skill Score (ApSS).",
#   'metrics': ['True Skill Statistics (TSS)',
#    'Accuracy (ACC)',
#    'Heidke Skill Score (HSS)',
#    'Appleman Skill Score (ApSS)'],
#   'limitations': ["The model's performance may be affected by the projection effect near the solar limb.",
#    'The study does not directly compare the model with all existing flare prediction models due to differences in data and evaluation methods.',
#    'The Grad-CAM and guided backpropagation methods may highlight regions that are not directly interpretable in physical terms.'],
#   'reproducibility': 3,
#   'strengths': 'The study provides a novel approach to interpreting deep learning models for solar flare prediction using attribution methods. It successfully highlights the importance of physical features such as the polarity inversion line (PIL) and correlates model predictions with established physical parameters (SHARP). The model achieves high performance metrics, indicating its reliability.',
#   'weaknesses': "The reliance on JPG format magnetograms may introduce artifacts that affect model performance. The attribution methods used may not fully capture the complexity of the model's decision-making process. The study does not explore the potential of other advanced models or attribution techniques that could provide deeper insights.",
#   'metrics_list': [{'True Skill Statistics (TSS)': 0.65},
#    {'Accuracy (ACC)': 0.83},
#    {'Heidke Skill Score (HSS)': 0.65},
#    {'Appleman Skill Score (ApSS)': 0.61}],
#   'scores': [0.65, 0.83, 0.65, 0.61]},
#  {'title': 'Improved AI-generated Solar Farside Magnetograms by STEREO and SDO Data Sets and Their Release',
#   'author': 'Jeong et al.',
#   'id': '10.3847/2041-8213/ac9116',
#   'data': ['SDO/AIA EUV images (304, 193, 171 Å)',
#    'SDO/HMI LOS magnetograms',
#    'STEREO/EUVI EUV observations (304, 195, 171 Å)'],
#   'code_link': 'https://github.com/JeongHyunJin/Pix2PixCC',
#   'packages_used': ['PyTorch',
#    'NumPy',
#    'Matplotlib',
#    'SciPy',
#    'Astropy',
#    'SunPy'],
#   'task': 'Solar farside magnetogram generation',
#   'field': 'Solar Physics',
#   'keywords': 'solar magnetograms, deep learning, Pix2Pix, GAN, solar farside, STEREO, SDO, image translation, AI-generated data, solar cycles 24 and 25, active regions, quiet regions, polar fields',
#   'abstract': 'The paper presents an improved deep-learning model, Pix2PixCC, for generating solar farside magnetograms using data from STEREO and SDO. The model incorporates correlation coefficients (CCs) in its objective functions and uses multichannel EUV images along with frontside SDO data pairs for training. The generated magnetograms show improved consistency with real magnetograms, with average pixel-to-pixel CCs of 0.88 for full disk, 0.91 for active regions, and 0.70 for quiet regions. The model successfully captures magnetic flux distributions and polarities, making it possible to monitor the temporal evolution of active regions across the entire solar surface. The AI-generated magnetograms are publicly available at the Korean Data Center for SDO.',
#   'models': ['Pix2PixCC (modified Pix2Pix with correlation coefficient-based objectives)'],
#   'hybrid_model': False,
#   'preprocessing': ['Alignment of images to match rotational axis, pixel size, and disk center location',
#    'Downsampling from 4096 × 4096 to 1024 × 1024 resolution',
#    'Masking areas outside 0.998 solar radii to minimize limb data uncertainty',
#    'Scaling EUV data numbers by median values to calibrate instrument degradation',
#    'Exclusion of poor-quality data flagged by nonzero QUALITY keyword',
#    'Selection of ARs and QRs based on total unsigned magnetic flux (TUMF) thresholds'],
#   'citations': ['Kim et al. (2019)',
#    'Jeong et al. (2020)',
#    'Isola et al. (2017)',
#    'Wang et al. (2018)',
#    'Goodfellow et al. (2016)',
#    'Mao et al. (2017)',
#    'Lawrence & Lin (1989)',
#    'Kingma & Ba (2014)',
#    'Rana et al. (2019)',
#    'Marnerides et al. (2021)',
#    'Vallejos et al. (2020)',
#    'Atmaja & Akagi (2021)',
#    'Ugarte-Urra et al. (2015)',
#    'Higgins et al. (2011)',
#    'Sun et al. (2015)'],
#   'approach_used': ['Deep learning-based image-to-image translation',
#    'Use of correlation coefficients in loss functions',
#    'Multichannel EUV image inputs',
#    'Incorporation of frontside SDO data pairs for reference',
#    'Evaluation using pixel-to-pixel correlation and magnetic flux comparisons'],
#   'methodology': 'The study introduces the Pix2PixCC model, an enhanced version of the Pix2Pix model, which incorporates correlation coefficients (CCs) into its loss functions to improve the generation of solar farside magnetograms. The model is trained using multichannel EUV images (304, 193, and 171 Å) from STEREO and SDO, along with frontside SDO data pairs consisting of EUV images and magnetograms observed 27.3 days prior. The training data spans from 2011 to 2021, with preprocessing steps including alignment, downsampling, masking, and scaling. The model is evaluated using test data not included in the training, with metrics such as pixel-to-pixel correlation, total unsigned magnetic flux (TUMF), and net magnetic flux (NMF) comparisons. The generated magnetograms, referred to as AISFMs 3.0, show significant improvements in accuracy and consistency with real magnetograms, enabling continuous monitoring of active regions across the solar surface.',
#   'metrics': ['pixel-to-pixel CC (full disk)',
#    'pixel-to-pixel CC (active regions)',
#    'pixel-to-pixel CC (quiet regions)',
#    'TUMF CC (full disk)',
#    'TUMF CC (active regions)',
#    'TUMF CC (quiet regions)',
#    'NMF CC (full disk)',
#    'NMF CC (active regions)',
#    'NMF CC (quiet regions)',
#    'SSIM (active regions)',
#    'SSIM (active regions, 8×8 binning)'],
#   'limitations': ['Physical quantities based on pixel-to-pixel distribution (e.g., neutral line) may not be exact.',
#    'Small-scale magnetic field configurations, such as magnetic cancellation features, may not be well reproduced.',
#    'Difficulty in predicting polarity distributions of rapidly emerging active regions not observed in reference datasets.',
#    'Dependence on the availability and quality of STEREO and SDO data.'],
#   'reproducibility': 4,
#   'strengths': 'The Pix2PixCC model significantly improves the accuracy of AI-generated solar farside magnetograms by incorporating correlation coefficients into the loss functions and using multichannel EUV images along with frontside SDO data pairs. The generated magnetograms (AISFMs 3.0) show high consistency with real magnetograms, as evidenced by improved pixel-to-pixel correlation coefficients and magnetic flux comparisons. This approach allows for continuous monitoring of active regions across the entire solar surface and provides valuable data for studying solar magnetic field evolution and coronal magnetic field extrapolation.',
#   'weaknesses': "The model's reliance on historical frontside data pairs may limit its ability to accurately predict rapidly emerging active regions or those with atypical polarity distributions. Additionally, the exclusion of certain EUV wavelengths (e.g., 94 and 131 Å) due to instrument limitations on STEREO may affect the detection of strong magnetic fluxes in some active regions. The spatial resolution of the generated magnetograms is also reduced due to downsampling, which may impact the analysis of fine-scale magnetic features.",
#   'metrics_list': [{'pixel-to-pixel CC (full disk)': 0.88},
#    {'pixel-to-pixel CC (active regions)': 0.91},
#    {'pixel-to-pixel CC (quiet regions)': 0.7},
#    {'TUMF CC (full disk)': 0.99},
#    {'TUMF CC (active regions)': 0.94},
#    {'TUMF CC (quiet regions)': 0.94},
#    {'NMF CC (full disk)': 0.9},
#    {'NMF CC (active regions)': 0.94},
#    {'NMF CC (quiet regions)': 0.96},
#    {'SSIM (active regions)': 0.74},
#    {'SSIM (active regions, 8×8 binning)': 0.93}],
#   'scores': [0.88, 0.91, 0.7, 0.99, 0.94, 0.94, 0.9, 0.94, 0.96, 0.74, 0.93]},
#  {'title': 'Construction of global IGS-3D electron density (Ne) model by deep learning',
#   'author': 'Ji et al.',
#   'id': '10.1016/j.jastp.2024.106370',
#   'data': ['International Global Navigation Satellite Systems (GNSS) Service (IGS) total electron content (TEC) data',
#    'International Reference Ionosphere (IRI-2016) model data',
#    'Incoherent Scatter Radar (ISR) data from Jicamarca, Millstone Hill, and EISCAT stations'],
#   'code_link': 'None provided',
#   'packages_used': ['PyTorch'],
#   'task': 'Global 3-D ionospheric electron density distribution modeling',
#   'field': 'Ionospheric Physics',
#   'keywords': 'deep learning, ionospheric electron density profile, IGS TEC, MLP, ionosphere modeling, inversion method',
#   'abstract': "This study presents a deep learning-based method to construct a global 3-D electron density (Ne) model using International GNSS Service (IGS) total electron content (TEC) data. The model employs a Multi-Layer Perceptron (MLP) to generate vertical electron density profiles from TEC values. The IRI-2016 model data from 2001 to 2013 were used for training, validation, and testing. The IGS-3D Ne model was evaluated by comparing its electron density profiles with those from Incoherent Scatter Radars (ISRs) at Jicamarca, Millstone Hill, and EISCAT stations. Results show that the IGS-3D Ne model's electron density profiles are closer to ISR observations than those of the IRI model, particularly at high latitudes. The model demonstrates improved accuracy with RMSE values of 0.37, 0.22, and 0.34 (log m^-3) at Jicamarca, Millstone Hill, and EISCAT stations, respectively.",
#   'models': ['Multi-Layer Perceptron (MLP)'],
#   'hybrid_model': False,
#   'multimodal': [],
#   'preprocessing': ['Normalization of input data to a range of [-1, 1]',
#    'Trigonometric function-based normalization for day of the year (DOY), universal time (UT), local time (LT), geographic latitude, and longitude',
#    'Linear interpolation of ISR electron density profiles to a regular altitude step of 25 km'],
#   'citations': ['Bilitza (2001)',
#    'Bilitza and Reinisch (2008)',
#    'Bilitza et al. (2017, 2022)',
#    'Hajj and Romans (1998)',
#    'Yue et al. (2012)',
#    'Li et al. (2021a, 2021b)',
#    'Sai Gowtam and Tulasi Ram (2017)',
#    'Liu et al. (2020)',
#    'Ji et al. (2020)',
#    'Lee et al. (2021)',
#    'Sai Gowtam et al. (2019)',
#    'Jang et al. (2021)',
#    'Lee et al. (2022)',
#    'Kumar et al. (2015)',
#    'Jee et al. (2005)',
#    'Themens et al. (2014)',
#    'Themens and Jayachandran (2016)',
#    'Yizengaw et al. (2008)',
#    'Jee et al. (2010)',
#    'Ogwala et al. (2021)'],
#   'approach_used': ['Inversion method to derive electron density profiles from TEC values',
#    'Deep learning-based modeling using MLP',
#    'Comparison with empirical IRI model and ISR observations'],
#   'methodology': "The study employs a deep learning approach using an MLP to construct a global 3-D electron density model from IGS TEC data. The model is trained on IRI-2016 data, which includes vertical electron density profiles and corresponding TEC values. The trained model generates electron density profiles from TEC values, which are then compared with ISR observations at three stations (Jicamarca, Millstone Hill, and EISCAT). The evaluation metrics include RMSE values, which indicate that the IGS-3D Ne model's profiles are closer to ISR observations than the IRI model's profiles, especially at high latitudes.",
#   'metrics': ['RMSE (log m^-3) - Jicamarca',
#    'RMSE (log m^-3) - Millstone Hill',
#    'RMSE (log m^-3) - EISCAT'],
#   'limitations': ["The IRI model's limitations at low latitudes due to equatorial ionization anomaly (EIA) effects.",
#    'Potential errors due to plasmaspheric contributions in IGS TEC, especially during nighttime.',
#    'Dependence on the accuracy of IGS TEC data for generating electron density profiles.',
#    'Limited availability of ISR data for comprehensive validation.'],
#   'reproducibility': 3,
#   'strengths': "The IGS-3D Ne model demonstrates improved accuracy in predicting global electron density profiles compared to the IRI model, particularly at high latitudes. The model's reliance on TEC values alone simplifies the input requirements while maintaining robust performance. The use of deep learning and inversion methods provides a scalable approach for real-time or near-real-time ionospheric modeling.",
#   'weaknesses': "The model's performance is constrained by the accuracy of the IRI-2016 training data, which may not fully capture ionospheric variability during extreme solar or geomagnetic conditions. The potential errors introduced by plasmaspheric contributions to IGS TEC, particularly at night, are not fully addressed. The evaluation is limited to specific ISR stations, which may not represent global ionospheric conditions comprehensively.",
#   'metrics_list': [{'RMSE (log m^-3) - Jicamarca': 0.37},
#    {'RMSE (log m^-3) - Millstone Hill': 0.22},
#    {'RMSE (log m^-3) - EISCAT': 0.34}],
#   'scores': [0.37, 0.22, 0.34]},
#  {'title': 'Generation of He I 1083 nm Images from SDO AIA Images by Deep Learning',
#   'author': '(Son) et al.',
#   'id': '10.3847/1538-4357/ac11ae',
#   'data': ['SDO/AIA 19.3 nm images',
#    'SDO/AIA 30.4 nm images',
#    'He I 1083 nm images from NSO/SOLIS'],
#   'code_link': 'None provided',
#   'packages_used': ['Sunpy', 'AIAPrep'],
#   'task': 'Generation of He I 1083 nm images from SDO/AIA images',
#   'field': 'Solar Chromosphere and Transition Region',
#   'keywords': 'deep learning, image-to-image translation, pix2pixHD, conditional GAN (cGAN), He I 1083 nm, SDO/AIA, solar chromosphere, coronal holes, filaments, active regions',
#   'abstract': 'The study presents a deep learning method (pix2pixHD) based on conditional Generative Adversarial Networks (cGAN) to generate He I 1083 nm images from SDO/AIA images. Three models were developed: Model I (single-input 19.3 nm), Model II (single-input 30.4 nm), and Model III (double-input 19.3 and 30.4 nm). The models were evaluated using metrics such as correlation coefficient (CC) and root mean square error (RMSE), with Model III showing the best performance (CC: 0.88, RMSE: 9.49). The synthetic images successfully reproduced observational features like active regions, filaments, and coronal holes, demonstrating the potential of this method for studying the time evolution of the chromosphere and transition region.',
#   'models': ['pix2pixHD'],
#   'hybrid_model': False,
#   'multimodal': ['N/A'],
#   'baselines': ['pix2pix (Isola et al., 2017)'],
#   'preprocessing': ['Quality filtering (quality index of zero in header information)',
#    "Level 1.5 image processing using Sunpy's aiaprep library (rotating, centering, aligning axis)",
#    'Exposure normalization (dividing data number by exposure time)',
#    'Scaling data to 0 to 2^12 DN/s',
#    'Calibration by dividing by median values on the solar disk',
#    'Logarithmic transformation',
#    'Resizing images to 1024x1024 pixels',
#    'Visual inspection and removal of improper He I 1083 nm data'],
#   'citations': ['Isola et al. (2017)',
#    'Wang et al. (2018)',
#    'Goodfellow et al. (2014)',
#    'Mirza and Osindero (2014)',
#    'Mao et al. (2017)',
#    'Kingma and Ba (2014)',
#    'Harvey and Recely (2002)',
#    'Henney and Harvey (2005)',
#    'Schmahl and Orrall (1979)',
#    'Andretta and Jones (1997)'],
#   'approach_used': ['Image-to-image translation using pix2pixHD',
#    'Conditional GAN (cGAN) for generating synthetic images',
#    'Multiscale discriminators for high-resolution image generation'],
#   'methodology': 'The study uses the pix2pixHD model, a deep learning method based on conditional Generative Adversarial Networks (cGAN), to generate He I 1083 nm images from SDO/AIA images. Three models were developed: Model I (19.3 nm input), Model II (30.4 nm input), and Model III (both 19.3 and 30.4 nm inputs). The models were trained on data from 2010 October to 2015 July, excluding June and December, and tested on the remaining data. The pix2pixHD architecture includes a generator and two discriminators (A and B) operating at different image scales to enhance image quality. The Least Squares GAN (LSGAN) loss and feature matching loss were used to optimize the model. The synthetic images were evaluated using metrics such as correlation coefficient (CC) and root mean square error (RMSE), with Model III showing the highest performance. The study highlights the potential of deep learning to generate high-quality, high-cadence He I 1083 nm images, useful for studying the chromosphere and transition region.',
#   'metrics': ['CC (Model I)',
#    'RMSE (Model I)',
#    'CC (Model II)',
#    'RMSE (Model II)',
#    'CC (Model III)',
#    'RMSE (Model III)'],
#   'limitations': ['Differences in filament absorption mechanisms between input and target wavelengths',
#    'Limited training data for capturing detailed filament structures',
#    'Limb darkening issues in He I 1083 nm data affecting polar coronal hole visibility',
#    'Potential artifacts in high-resolution image generation'],
#   'reproducibility': 4,
#   'strengths': 'The study successfully demonstrates the use of deep learning (pix2pixHD) to generate high-quality He I 1083 nm images from SDO/AIA images. The synthetic images show high correlation with real observations and effectively reproduce key solar features such as coronal holes, filaments, and active regions. The method overcomes limitations of ground-based observations, such as data gaps and variable seeing conditions, by providing uniform quality and high-cadence images. This approach has significant potential for improving the study of chromospheric and transition region phenomena.',
#   'weaknesses': "The study has some limitations, including differences in filament absorption mechanisms between input and target wavelengths, which can lead to discrepancies in filament representation. The limited training data may also affect the model's ability to capture detailed filament structures. Additionally, limb darkening issues in the He I 1083 nm data can obscure polar coronal holes, and there is a potential for artifacts in high-resolution image generation. The lack of publicly available code reduces the reproducibility of the results.",
#   'metrics_list': [{'CC (Model I)': 0.83},
#    {'RMSE (Model I)': 11.28},
#    {'CC (Model II)': 0.86},
#    {'RMSE (Model II)': 10.15},
#    {'CC (Model III)': 0.88},
#    {'RMSE (Model III)': 9.49}],
#   'scores': [0.83, 11.28, 0.86, 10.15, 0.88, 9.49]},
#  {'title': 'Can we properly determine differential emission measures from Solar Orbiter/EUI/FSI with deep learning?',
#   'author': 'Youn et al.',
#   'id': 'arXiv:2502.00001',
#   'data': ['SDO/AIA datasets (2011-2021)',
#    'Solar Orbiter/EUI/FSI datasets (2022 onwards)'],
#   'code_link': 'https://github.com/ianan/demreg/',
#   'packages_used': ['PyTorch', 'Astropy', 'aiapy', 'SunPy', 'NumPy'],
#   'task': 'Differential Emission Measure (DEM) determination',
#   'field': 'Solar Physics',
#   'keywords': 'deep learning, differential emission measure, Solar Orbiter, EUI/FSI, SDO/AIA, Pix2PixCC, solar corona, EUV images, AI-generated data, solar atmosphere',
#   'abstract': 'The study investigates the feasibility of using deep learning to determine differential emission measures (DEMs) from Solar Orbiter/EUI/FSI data, which only captures two EUV channels (174 and 304 Å). The authors trained deep learning models using the Pix2PixCC architecture on SDO/AIA data to generate five additional EUV channels (94, 131, 193, 211, and 335 Å). The AI-generated data were then used to calculate DEMs, which were compared with those derived from SDO/AIA observations. The results show that the AI-generated DEMs are consistent with those from SDO/AIA, suggesting that deep learning can effectively augment the limited FSI data for accurate DEM determination.',
#   'models': ['Pix2PixCC'],
#   'hybrid_model': False,
#   'multimodal': [],
#   'baselines': [{'baseline': 'Pix2PixHD (Wang et al., 2018)',
#     'citation': '(Wang et al., 2018)'}],
#   'preprocessing': ['Data normalization and logarithmic scaling',
#    'Resizing images to 1024x1024 pixels',
#    'Calibration of degradation in AIA imagers',
#    'Intercalibration between AIA and FSI datasets using third-order fitting'],
#   'citations': ['Müller et al. (2020)',
#    'Rochus et al. (2020)',
#    'Pesnell et al. (2012)',
#    'Lemen et al. (2012)',
#    'Schmelz et al. (2011)',
#    'Hannah & Kontar (2012)',
#    'Jeong et al. (2022)',
#    'Wang et al. (2018)',
#    'Lin (1989)',
#    "O'Dwyer et al. (2010)",
#    'Viall et al. (2020)',
#    'Park et al. (2023)',
#    'Boerner et al. (2012)',
#    'Ugarte-Urra et al. (2015)',
#    'Dere et al. (2023)',
#    'Wright et al. (2017)',
#    'Jarolim et al. (2024)',
#    'Aschwanden et al. (2008a)',
#    'Aschwanden et al. (2008b)'],
#   'approach_used': ['Image-to-image translation using Pix2PixCC',
#    'Regularized inversion method for DEM calculation',
#    'Intercalibration between AIA and FSI datasets'],
#   'methodology': 'The study utilized the Pix2PixCC deep learning model to generate five EUV channels (94, 131, 193, 211, and 335 Å) from the existing FSI 174 and 304 Å data. The generated data were then used to calculate differential emission measures (DEMs) using a regularized inversion method. The DEMs derived from AI-generated data were compared with those from SDO/AIA observations to validate the accuracy of the deep learning approach. The methodology involved training the model on SDO/AIA data, preprocessing the Solar Orbiter/EUI/FSI data to match the AIA data format, and applying the trained model to generate the additional EUV channels.',
#   'metrics': ['Pearson CC (94 Å)',
#    'Pearson CC (131 Å)',
#    'Pearson CC (193 Å)',
#    'Pearson CC (211 Å)',
#    'Pearson CC (335 Å)',
#    'RMSE (94 Å)',
#    'RMSE (131 Å)',
#    'RMSE (193 Å)',
#    'RMSE (211 Å)',
#    'RMSE (335 Å)',
#    'NRMSE (94 Å)',
#    'NRMSE (131 Å)',
#    'NRMSE (193 Å)',
#    'NRMSE (211 Å)',
#    'NRMSE (335 Å)'],
#   'limitations': ['Differences in response functions between AIA and FSI instruments can introduce discrepancies.',
#    'The performance of the 94 Å channel generation is lower due to its sensitivity to higher temperature plasma and noise.',
#    'Intercalibration between instruments needs improvement as the mission progresses.',
#    'Three-dimensional morphology of coronal loops can introduce errors in ROI selection.',
#    'The study does not address extreme events like solar flares, where deep learning performance may decline.'],
#   'reproducibility': 4,
#   'strengths': 'The study demonstrates a novel application of deep learning to augment limited observational data for DEM analysis. The Pix2PixCC model successfully generates additional EUV channels with high correlation to observed data, enabling more accurate DEM calculations. The methodology is well-documented, and the use of open-source tools enhances reproducibility.',
#   'weaknesses': "The study acknowledges discrepancies due to instrumental differences and the limitations of the 94 Å channel generation. The reliance on intercalibration between different instruments introduces potential errors, and the method's robustness during extreme solar events remains untested.",
#   'metrics_list': [{'Pearson CC (94 Å)': 0.87},
#    {'Pearson CC (131 Å)': 0.96},
#    {'Pearson CC (193 Å)': 0.95},
#    {'Pearson CC (211 Å)': 0.95},
#    {'Pearson CC (335 Å)': 0.93},
#    {'RMSE (94 Å)': 0.5},
#    {'RMSE (131 Å)': 1.26},
#    {'RMSE (193 Å)': 38.96},
#    {'RMSE (211 Å)': 13.55},
#    {'RMSE (335 Å)': 0.84},
#    {'NRMSE (94 Å)': 0.012},
#    {'NRMSE (131 Å)': 0.008},
#    {'NRMSE (193 Å)': 0.012},
#    {'NRMSE (211 Å)': 0.01},
#    {'NRMSE (335 Å)': 0.011}],
#   'scores': [0.87,
#    0.96,
#    0.95,
#    0.95,
#    0.93,
#    0.5,
#    1.26,
#    38.96,
#    13.55,
#    0.84,
#    0.012,
#    0.008,
#    0.012,
#    0.01,
#    0.011]},
#  {'title': 'Fast Reconstruction of 3D Density Distribution around the Sun Based on the MAS by Deep Learning',
#   'author': 'Rahman et al.',
#   'id': '10.3847/1538-4357/acc722',
#   'data': ['MAS thermodynamic model data (2010 June to 2022 April, CR 2097 to CR 2256)',
#    'SOHO/LASCO C3 coronagraph data'],
#   'code_link': 'None provided',
#   'packages_used': ['SunPy', 'PyTorch', 'NumPy'],
#   'task': '3D coronal electron density distribution reconstruction',
#   'field': 'Solar Corona and Inner Heliosphere',
#   'keywords': 'deep learning, pix2pixHD, solar corona, 3D density distribution, magnetohydrodynamics (MHD), space weather, GAN, image-to-image translation, Sun, solar physics, heliosphere',
#   'abstract': 'This study introduces a deep learning-based approach using the pix2pixHD model to generate a 3D coronal electron density distribution from photospheric solar magnetic fields. The method significantly reduces computation time compared to traditional magnetohydrodynamic (MHD) simulations. The study uses 155 pairs of Carrington rotations from 2010 to 2022 for training and testing 152 deep learning models, each corresponding to different solar radii up to 30 solar radii. The AI-generated 3D electron densities are highly consistent with MHD simulations, achieving an average correlation coefficient of 0.97. The computation time for testing data sets up to 30 solar radii is approximately 45.2 seconds using an NVIDIA TITAN XP GPU, which is much faster than the typical MAS simulation time. The synthetic coronagraphic images derived from the deep learning models are similar to SOHO/LASCO C3 coronagraph data, especially during solar minimum periods. This AI-generated coronal density distribution can be utilized for near-real-time space weather models.',
#   'models': ['pix2pixHD',
#    'U-Net',
#    'Least Squares Generative Adversarial Networks (LSGAN)'],
#   'hybrid_model': False,
#   'multimodal': [],
#   'preprocessing': ['Normalization of input data using mean and standard deviation',
#    'Normalization of density data at each solar radius',
#    'Data augmentation via flipping (longitude and latitude) and rotation by 10 degrees in the longitudinal direction',
#    'Application of random noise and Gaussian blur to input training data'],
#   'citations': ['Gómez (2018)',
#    'Vourlidas et al. (2000)',
#    'de Patoul et al. (2015)',
#    'Feng et al. (2015)',
#    'Usmanov (1998)',
#    'Linker (1999)',
#    'Riley et al. (2009)',
#    'Goodfellow et al. (2014)',
#    'Isola et al. (2017)',
#    'Wang et al. (2018)',
#    'Jang et al. (2021)',
#    'Mao et al. (2017)',
#    'Ronneberger et al. (2015)',
#    'Kingma & Ba (2014)'],
#   'approach_used': ['Image-to-image translation',
#    'Generative Adversarial Networks (GANs)',
#    'Conditional GANs (cGANs)',
#    'Feature Matching Loss (FM Loss)'],
#   'methodology': 'The study uses the pix2pixHD model, an advanced version of the pix2pix model, to perform image-to-image translation. The model architecture includes a U-Net-based generator and a single discriminator. The generator converts input photospheric magnetic field data into 3D coronal electron density distributions. The discriminator evaluates the generated outputs to ensure they are realistic. The model is trained using Least Squares GAN (LSGAN) loss and feature matching loss to stabilize training and improve performance. Data preprocessing includes normalization, augmentation via flipping and rotation, and adding noise to mimic real-world artifacts. The models are trained on 122 Carrington rotations and tested on 33 rotations, with a focus on both solar minimum and maximum periods.',
#   'metrics': ["Pearson's Correlation Coefficient (Solar Minimum)",
#    "Pearson's Correlation Coefficient (Solar Maximum)",
#    'Normalized RMS Error (NRMSE)'],
#   'limitations': ["The MAS simulation data used for training and testing are limited in quantity, which may affect the model's generalization.",
#    'The study does not address the generation of other plasma parameters like temperature and velocity, focusing solely on electron density.',
#    'Differences between AI-generated coronagraph images and observed SOHO/LASCO C3 images during solar maximum periods suggest potential inaccuracies in complex solar conditions.',
#    "The model's performance relies heavily on the quality and resolution of input photospheric magnetic field data."],
#   'reproducibility': 4,
#   'strengths': 'The study successfully demonstrates the use of deep learning to significantly reduce computation time for generating 3D coronal electron density distributions compared to traditional MHD simulations. The AI-generated results are highly consistent with MAS simulations, with an average correlation coefficient of 0.97. The approach is scalable and can be applied to near-real-time space weather forecasting. The synthetic coronagraphic images generated from the models are similar to actual observations, particularly during solar minimum periods.',
#   'weaknesses': "The study is limited by the quantity and quality of the MAS simulation data, which may impact the model's ability to generalize across different solar conditions. The AI-generated coronagraph images show discrepancies during solar maximum periods, indicating potential limitations in handling complex solar phenomena. The model currently focuses only on electron density and does not address other critical plasma parameters like temperature and velocity.",
#   'metrics_list': [{"Pearson's Correlation Coefficient (Solar Minimum)": 0.99},
#    {"Pearson's Correlation Coefficient (Solar Maximum)": 0.98},
#    {'Normalized RMS Error (NRMSE)': 0.08}],
#   'scores': [0.99, 0.98, 0.08]},
#  {'title': 'Solar farside magnetograms from deep learning analysis of STEREO/EUVI data',
#   'author': 'Kim et al.',
#   'id': '10.1038/s41550-019-0715-9',
#   'data': ['SDO/AIA 304-Å images',
#    'SDO/HMI line-of-sight magnetograms',
#    'STEREO/EUVI 304-Å images'],
#   'code_link': 'https://github.com/tykimos/SolarMagGAN',
#   'packages_used': ['NumPy', 'Keras'],
#   'task': 'Generation of farside solar magnetograms',
#   'field': 'Solar Physics',
#   'keywords': 'deep learning, solar magnetograms, farside magnetograms, image-to-image translation, conditional generative adversarial networks (cGANs), STEREO/EUVI, SDO/AIA, SDO/HMI',
#   'abstract': 'The paper presents a deep learning model based on conditional generative adversarial networks (cGANs) to generate farside solar magnetograms from STEREO/EUVI 304-Å images. The model was trained using pairs of SDO/AIA 304-Å images and SDO/HMI magnetograms from 2011 to 2017, excluding September and October each year. The evaluation shows that the generated magnetograms are highly comparable to SDO/HMI magnetograms, particularly in replicating Hale-patterned active regions. The method allows monitoring the temporal evolution of magnetic fields from the farside to the frontside of the Sun when farside extreme-ultraviolet data are available.',
#   'models': ['Conditional Generative Adversarial Networks (cGANs)'],
#   'hybrid_model': False,
#   'multimodal': ['N/A'],
#   'baselines': ['Isola et al. (2017)'],
#   'preprocessing': ['Calibrating, rotating, and centering images to create Level 1.5 images',
#    'Converting images to 8-bit scale with 1,024 by 1,024 pixels',
#    'Excluding poor-quality images (e.g., noisy images, incorrect header information, images affected by solar eclipses)'],
#   'citations': ['Solanki et al. (2006)',
#    'Lindsey and Braun (2000)',
#    'Braun and Lindsey (2001)',
#    'Lindsey and Braun (2017)',
#    'Goodfellow et al. (2014)',
#    'Isola et al. (2017)',
#    'Pesnell et al. (2012)',
#    'Lemen et al. (2012)',
#    'Schou et al. (2012)',
#    'Howard et al. (2008)',
#    'Kaiser et al. (2008)',
#    'Dere et al. (1997)',
#    'Landi et al. (2012)',
#    'Nitta et al. (2013)',
#    'Liu et al. (2012)'],
#   'approach_used': ['Image-to-image translation using cGANs',
#    'Training with paired SDO/AIA and SDO/HMI data',
#    'Quantitative evaluation using correlation coefficients, relative error, and normalized mean square error'],
#   'methodology': 'The study uses a cGAN-based model to translate SDO/AIA 304-Å images into magnetograms. The model was trained on 4,147 pairs of images and evaluated on 825 pairs. The generator network was trained to minimize the error between HMI magnetograms and AI-generated magnetograms, while the discriminator network was trained to distinguish real pairs from AI-generated pairs. The evaluation included comparing total unsigned magnetic flux (TUMF), pixel-to-pixel correlation, relative error, and normalized mean square error between HMI and AI-generated magnetograms for full disk, active regions, and quiet regions.',
#   'metrics': ['Correlation Coefficient (CC) for TUMF',
#    'Pixel-to-Pixel CC (8x8 binning)',
#    'Relative Error (R1) of TUMF (Mean)',
#    'Relative Error (R1) of TUMF (Standard Deviation)',
#    'Normalized Mean Square Error (R2) of Magnetic Field (Mean)',
#    'Normalized Mean Square Error (R2) of Magnetic Field (Standard Deviation)'],
#   'limitations': ['The model may not accurately reproduce the tilt angle between preceding and following sunspots.',
#    'The model is trained on data from the 24th solar cycle and may not generalize well to odd solar cycles.',
#    'Discrepancies in detailed structures between real and AI-generated magnetograms due to differences in chromospheric and photospheric measurements.',
#    'Overestimation of total unsigned magnetic flux (TUMF) by about 6.7%.',
#    'Uncertainty in magnetic flux estimation from farside magnetograms due to calibration differences between AIA and EUVI.'],
#   'reproducibility': 4,
#   'strengths': 'The study successfully demonstrates the use of cGANs for generating high-quality farside solar magnetograms from EUV images. The generated magnetograms are highly comparable to SDO/HMI magnetograms, particularly in replicating Hale-patterned active regions. The method allows for monitoring the temporal evolution of magnetic fields from the farside to the frontside of the Sun, which is valuable for space weather forecasting. The code and data are publicly available, enhancing reproducibility.',
#   'weaknesses': "The model's performance is limited in accurately reproducing the tilt angle of sunspots and generalizing to odd solar cycles. There are discrepancies in detailed structures between real and AI-generated magnetograms, and the model tends to overestimate the total unsigned magnetic flux. The uncertainty in magnetic flux estimation from farside magnetograms due to calibration differences between AIA and EUVI is also a notable weakness.",
#   'metrics_list': [{'Correlation Coefficient (CC) for TUMF': {'Full Disk': 0.97,
#      'Active Regions': 0.95,
#      'Quiet Regions': 0.74}},
#    {'Pixel-to-Pixel CC (8x8 binning)': {'Full Disk': 0.77,
#      'Active Regions': 0.66,
#      'Quiet Regions': 0.21}},
#    {'Relative Error (R1) of TUMF (Mean)': {'Full Disk': 0.067,
#      'Active Regions': 0.072,
#      'Quiet Regions': 0.091}},
#    {'Relative Error (R1) of TUMF (Standard Deviation)': {'Full Disk': 0.036,
#      'Active Regions': 0.019,
#      'Quiet Regions': 0.075}},
#    {'Normalized Mean Square Error (R2) of Magnetic Field (Mean)': {'Full Disk': 0.053,
#      'Active Regions': 0.125,
#      'Quiet Regions': 0.041}},
#    {'Normalized Mean Square Error (R2) of Magnetic Field (Standard Deviation)': {'Full Disk': 0.008,
#      'Active Regions': 0.049,
#      'Quiet Regions': 0.005}}],
#   'scores': [{'Full Disk': 0.97,
#     'Active Regions': 0.95,
#     'Quiet Regions': 0.74},
#    {'Full Disk': 0.77, 'Active Regions': 0.66, 'Quiet Regions': 0.21},
#    {'Full Disk': 0.067, 'Active Regions': 0.072, 'Quiet Regions': 0.091},
#    {'Full Disk': 0.036, 'Active Regions': 0.019, 'Quiet Regions': 0.075},
#    {'Full Disk': 0.053, 'Active Regions': 0.125, 'Quiet Regions': 0.041},
#    {'Full Disk': 0.008, 'Active Regions': 0.049, 'Quiet Regions': 0.005}]},
#  {'title': 'Three-day Forecasting of Solar Wind Speed Using SDO/AIA Extreme-ultraviolet Images by a Deep-learning Model',
#   'author': 'Son et al.',
#   'id': '10.3847/1538-4357/ace04e',
#   'data': ['SDO/AIA 211 and 193 Å EUV images',
#    'OMNIWeb solar wind speed data'],
#   'code_link': 'None provided',
#   'packages_used': ['SolarSoft library for preprocessing',
#    'TensorFlow/Keras (implied by model architecture)'],
#   'task': 'Solar wind speed prediction',
#   'field': 'Space weather, solar wind',
#   'keywords': 'deep learning, solar wind speed prediction, convolutional neural networks, LSTM, Inception block, space weather forecasting, coronal holes, EUV images',
#   'abstract': 'This study presents a deep-learning model designed to forecast solar wind speed for the next 3 days with a 6-hour cadence. The model uses SDO/AIA 211 and 193 Å EUV images and solar wind speed data from the past 5 days as input. The model architecture consists of two networks: a convolutional layer-based network for processing images and a dense layer-based network for handling solar wind speed data. The model successfully predicts solar wind speed variations, achieving an RMSE ranging from 37.4 km/s (for 6-hour predictions) to 68.2 km/s (for 72-hour predictions) and correlation coefficients from 0.92 to 0.67. The model outperforms previous studies and the WSA-ENLIL model, particularly in predicting high-speed streams caused by equatorial coronal holes. However, it struggles to predict solar wind speed enhancements caused by coronal mass ejections (CMEs).',
#   'models': ['Convolutional Neural Network (Inception block)',
#    'Long Short-Term Memory (LSTM)',
#    'Dense layers'],
#   'hybrid_model': True,
#   'multimodal': ['Image data (EUV)', 'Time-series data (solar wind speed)'],
#   'baselines': ['WSA-ENLIL model (Wang-Sheely-Arge-ENLIL) (Wang & Sheeley, 1990; Arge & Pizzo, 2000)'],
#   'preprocessing': ['Rotating and centering EUV images',
#    'Exposure compensation',
#    'Degradation compensation using SolarSoft library',
#    'Resizing images to 64x64 pixels',
#    'Averaging solar wind speed data to 6-hour cadence'],
#   'citations': ['Son et al. (2023)',
#    'Upendran et al. (2020)',
#    'Sun et al. (2021)',
#    'Raju & Das (2021)',
#    'Odstrcil (2003)',
#    'Wang & Sheeley (1990)',
#    'Arge & Pizzo (2000)'],
#   'approach_used': ['Multimodal deep learning',
#    'Hybrid architecture (CNN + LSTM + Dense layers)',
#    'Sequential prediction'],
# ...
#   'packages_used': ['SolarSoftWare (SSW)', 'PyTorch'],
#   'task': 'Solar coronal magnetic field extrapolation',
#   'field': 'Solar magnetic fields',
#   'keywords': 'solar magnetic fields, solar corona, convolutional neural networks, deep learning, Pix2PixHD, space weather, AI-generated magnetograms, synchronic maps, PFSS model',
#   'abstract': 'The paper introduces a novel method for extrapolating global coronal magnetic fields using near-real-time frontside and AI-generated farside magnetic fields. The authors use a deep learning model (Pix2PixHD) trained on SDO/AIA EUV images and SDO/HMI magnetograms to generate farside magnetograms from STEREO observations. The generated magnetograms are used to create synchronic maps, which are then used in the Potential Field Source Surface (PFSS) model to extrapolate coronal magnetic fields. The results show improved consistency with coronal observations compared to conventional methods, particularly in representing active regions and coronal holes.',
#   'models': ['Pix2PixHD'],
#   'hybrid_model': False,
#   'multimodal': ['EUV images and magnetograms'],
#   'baselines': [['Previous farside magnetogram generation model (Kim et al., 2019)',
#     'Pix2Pix model (Isola et al., 2017)']],
#   'preprocessing': ['Calibration, rotation, and centering of images using SSW packages',
#    'Downsampling to 1024x1024 pixels',
#    'Masking areas outside 0.98 solar radii',
#    'Scaling EUV data by median values and normalizing logarithms',
#    'Saturation limits of ±3000 Gauss for magnetograms',
#    'Exclusion of poor-quality data'],
#   'citations': ['Jess et al. (2016)',
#    'Amari et al. (2018)',
#    'Inoue et al. (2018)',
#    'Mikić et al. (2018)',
#    'Nandy et al. (2018)',
#    'Bertello et al. (2014)',
#    'DeVore et al. (1984)',
#    'Schrijver & DeRosa (2003)',
#    'Huang et al. (2018)',
#    'Park et al. (2018)',
#    'Illarionov & Tlatov (2018)',
#    'Kim et al. (2019)',
#    'Isola et al. (2017)',
#    'Mirza & Osindero (2014)',
#    'KPL19 (Kim et al., 2019)',
#    'Wang et al. (2018)',
#    'Shin et al. (2020)',
#    'Kaiser et al. (2008)',
#    'Howard et al. (2008)',
#    'Pesnell et al. (2011)',
#    'Lemen et al. (2011)',
#    'Scherrer et al. (2012)',
#    'Freeland & Handy (1998)',
#    'Chen & Koltun (2017)',
#    'Ugarte-Urra et al. (2015)',
#    'Liewer et al. (2017)',
#    'Sun et al. (2011)',
#    'Pastor Yabar et al. (2015)',
#    'Hickmann et al. (2015)',
#    'Riley et al. (2006)',
#    'Hakamada et al. (2005)',
#    'Pomoell & Poedts (2018)',
#    'Lowder et al. (2014)',
#    'Wang et al. (1996)',
#    'Lee et al. (2011)',
#    'Wang & Sheeley (1992)',
#    'Goodfellow et al. (2016)',
#    'Subramanian (2018)',
#    'Kingma & Ba (2015)',
#    'Buduma & Locascio (2017)'],
#   'approach_used': ['Deep learning-based image translation (Pix2PixHD)',
#    'PFSS model for coronal magnetic field extrapolation'],
#   'methodology': 'The methodology involves training a Pix2PixHD model on SDO/AIA EUV images and SDO/HMI magnetograms to generate farside magnetograms from STEREO observations. These generated magnetograms are integrated into synchronic maps, replacing conventional farside data. The synchronic maps are then used as input for the PFSS model to extrapolate the coronal magnetic fields. The results are validated by comparing with EUV observations, showing improved accuracy in representing active regions and coronal holes.',
#   'metrics': ['Correlation Coefficients (CC) for Total Unsigned Magnetic Flux (TUMF)',
#    'Correlation Coefficients (CC) for Net Magnetic Flux (NMF)',
#    'Mean Pixel-to-Pixel CC (8×8 binning)'],
#   'limitations': ['Dependence on the quality and availability of STEREO data',
#    'Limited to the dynamic range of ±3000 Gauss',
#    'Potential inaccuracies in rapid flux emergence or disappearance near the limb',
#    'Computational resources required for training and inference'],
#   'reproducibility': 4,
#   'strengths': 'The paper presents a significant advancement in generating near-real-time farside magnetograms using deep learning, improving the accuracy of coronal magnetic field extrapolations. The integration of AI-generated data with traditional models like PFSS enhances the representation of active regions and coronal holes, offering better consistency with observations. The methodology is well-documented, and the code is publicly available, promoting reproducibility and further research.',
#   'weaknesses': "The model's performance is constrained by the availability and quality of STEREO data. The dynamic range limitation of ±3000 Gauss may not capture extreme magnetic field strengths accurately. The computational requirements for training and inference could be a barrier for some researchers. Additionally, the model may struggle with rapid changes in magnetic fields near the solar limb, affecting the accuracy of the generated magnetograms.",
#   'metrics_list': [{'Correlation Coefficients (CC) for Total Unsigned Magnetic Flux (TUMF)': {'Full Disk': 0.99,
#      'Active Regions (ARs)': 0.95,
#      'Quiet Regions (QRs)': 0.98}},
#    {'Correlation Coefficients (CC) for Net Magnetic Flux (NMF)': {'Full Disk': 0.86,
#      'Active Regions (ARs)': 0.93,
#      'Quiet Regions (QRs)': 0.97}},
#    {'Mean Pixel-to-Pixel CC (8×8 binning)': {'Full Disk': 0.81,
#      'Active Regions (ARs)': 0.79,
#      'Quiet Regions (QRs)': 0.62}}],
#   'scores': [{'Full Disk': 0.99,
#     'Active Regions (ARs)': 0.95,
#     'Quiet Regions (QRs)': 0.98},
#    {'Full Disk': 0.86,
#     'Active Regions (ARs)': 0.93,
#     'Quiet Regions (QRs)': 0.97},
#    {'Full Disk': 0.81,
#     'Active Regions (ARs)': 0.79,
#     'Quiet Regions (QRs)': 0.62}]},
#  {'title': 'Generation of Solar UV and EUV Images from SDO/HMI Magnetograms by Deep Learning',
#   'author': 'Park et al.',
#   'id': '10.3847/2041-8213/ab4a8c',
#   'data': ['SDO/HMI line-of-sight (LOS) magnetograms',
#    'SDO/AIA nine-passband (94, 131, 171, 193, 211, 304, 335, 1600, and 1700 Å) UV/EUV images'],
#   'code_link': 'https://github.com/eunsupark/solar_euv_generation',
#   'packages_used': ['NumPy', 'Keras', 'TensorFlow', 'SunPy', 'SolarSoft'],
#   'task': 'Image-to-image translation from solar magnetograms to solar UV and EUV images',
#   'field': 'Solar Physics',
#   'keywords': 'deep learning, image-to-image translation, solar UV images, solar EUV images, solar magnetograms, convolutional neural networks (CNN), generative adversarial networks (GAN), conditional GAN (cGAN)',
#   'abstract': 'The paper applies deep learning methods to translate solar magnetograms into solar ultraviolet (UV) and extreme ultraviolet (EUV) images. Two convolutional neural network models are considered: Model A, which uses L1 loss, and Model B, which uses L1 loss combined with conditional GAN (cGAN) loss. The models are trained using pairs of SDO/AIA UV/EUV images and corresponding SDO/HMI magnetograms from 2011 to 2016. The models are evaluated by comparing generated images with actual SDO/AIA images from 2017. Model A generally performs slightly better in terms of pixel-to-pixel correlation, relative error, and percentage of pixels with errors less than 10%, while Model B generates less blurred images due to the inclusion of cGAN loss.',
#   'models': ['CNN with L1 loss (Model A)',
#    'CNN with L1 and cGAN loss (Model B)'],
#   'hybrid_model': False,
#   'multimodal': [],
#   'baselines': [],
#   'preprocessing': ['Calibration, rotation, and centering of images to create level 1.5 images.',
#    'Division of AIA images by exposure time to ensure homogeneous exposure conditions.',
#    'Compensation for instrument degradation using SolarSoft routine (aia_get_response.pro).',
#    'Coalignment of AIA and HMI images by fixing the solar disk size.',
#    'Downsampling images to 1024x1024 pixels.',
#    'Conversion of AIA data to log scale (0-14) and rescaling to (-1 to 1).',
#    'Exclusion of poor-quality images (e.g., noisy images due to solar flares, incorrect header information).'],
#   'citations': ['Galvez et al. (2019)',
#    'Kim et al. (2019)',
#    'Isola et al. (2016)',
#    'Goodfellow et al. (2014)',
#    'Lecun et al. (2015)',
#    'Lecun et al. (1998)',
#    'Mirza & Osindero (2014)',
#    'Radford et al. (2015)',
#    'Kingma & Ba (2014)'],
#   'approach_used': ['Image-to-image translation using CNN models.',
#    'Training with L1 loss (Model A) and L1 + cGAN loss (Model B).',
#    'Quantitative evaluation using pixel-to-pixel correlation coefficient, relative error, and percentage of pixels with errors less than 10%.'],
#   'methodology': 'The study employs two CNN models for translating SDO/HMI magnetograms into SDO/AIA UV/EUV images. Model A uses L1 loss to minimize pixel-wise differences between generated and real images, while Model B combines L1 and cGAN loss to enhance realism in generated images. The models are trained on a dataset of 9985 pairs of SDO/HMI magnetograms and SDO/AIA UV/EUV images from 2011 to 2016. The data is preprocessed to ensure consistency and quality, including calibration, exposure normalization, and degradation correction. The models are evaluated on a test set from 2017 using metrics such as pixel-to-pixel correlation, relative error, and the percentage of pixels with errors less than 10%. Model A generally performs better in terms of these metrics, but Model B produces less blurred images due to the cGAN loss.',
#   'metrics': ['Pixel-to-pixel correlation coefficient (CC)',
#    'Relative error (RE)',
#    'Percentage of pixels with errors less than 10% (PPE10)',
#    'Root mean square contrast measure (CM)'],
#   'limitations': ['The models may not fully capture small-scale structures in the generated images.',
#    'The study does not account for solar cycle phase effects or time-varied AIA degradation effects due to the chronological separation of training, validation, and test datasets.',
#    'Generated images may still exhibit some blurriness, particularly in Model A.'],
#   'reproducibility': 4,
#   'strengths': 'The paper demonstrates the successful application of deep learning techniques for translating solar magnetograms into UV and EUV images. The use of two different models (with and without cGAN loss) provides insights into the trade-offs between accuracy and image realism. The methodology is well-documented, and the code is publicly available, enhancing reproducibility.',
#   'weaknesses': "The study's reliance on chronologically separated datasets may limit the generalizability of the models across different phases of the solar cycle. The evaluation metrics, while comprehensive, do not fully address the realism of generated images beyond pixel-wise comparisons. The potential for overfitting or underfitting is not extensively discussed.",
#   'metrics_list': [{'Pixel-to-pixel correlation coefficient (CC)': 0.84},
#    {'Relative error (RE)': 0.07},
#    {'Percentage of pixels with errors less than 10% (PPE10)': 46.2},
#    {'Root mean square contrast measure (CM)': 47.6}],
#   'scores': [0.84, 0.07, 46.2, 47.6]},
#  {'title': 'Prediction of the Next Solar Rotation Synoptic Maps Using an Artificial Intelligence-based Surface Flux Transport Model',
#   'author': 'Jeong et al.',
#   'id': '10.3847/1538-4357/ad3295',
#   'data': ['Solar Dynamics Observatory/Helioseismic and Magnetic Imager (SDO/HMI) synoptic maps',
#    'Solar and Heliospheric Observatory/Michelson Doppler Imager (SOHO/MDI) synoptic maps',
#    'National Solar Observatory/Global Oscillation Network Group (NSO/GONG) synoptic maps'],
#   'code_link': 'https://github.com/antyeates1983/sft_data',
#   'packages_used': ['PyTorch',
#    'SunPy',
#    'Astropy',
#    'SciPy',
#    'NumPy',
#    'Matplotlib',
#    'Scikit-image'],
#   'task': 'Prediction of solar surface magnetic field evolution',
#   'field': 'Solar Physics',
#   'keywords': 'solar magnetic fields, deep learning, surface flux transport, synoptic maps, solar rotation, AI-based prediction, Pix2PixCC, U-Net, solar cycle, space weather',
#   'abstract': 'The study presents an AI-based model using the Pix2PixCC architecture to predict the evolution of solar surface magnetic fields over the next solar rotation (27.2753 days). The model is trained on synoptic maps from SDO/HMI, SOHO/MDI, and NSO/GONG, spanning 1996 to 2023. The AI-generated predictions are compared with the conventional Surface Flux Transport (SFT) model and a persistent model, showing improved performance in metrics such as RMSE, FSIM, and pixel-to-pixel correlation coefficient. The model successfully captures key solar phenomena like differential rotation and meridional flow, and it is evaluated on both real and synthetic data.',
#   'models': ['Pix2PixCC', 'U-Net'],
#   'hybrid_model': False,
#   'multimodal': ['N/A'],
#   'baselines': ['Persistent model (Jeong et al., 2024)',
#    'Conventional SFT model (Yeates et al., 2023)'],
#   'preprocessing': ['Interpolation of synoptic maps to a uniform 360x180 grid',
#    'Data augmentation by longitudinal shifting',
#    'Padding for spherical surface representation'],
#   'citations': ['Mackay & Yeates (2012)',
#    'Nandy et al. (2023)',
#    'Owens et al. (2014)',
#    'Vieira & Solanki (2010)',
#    'Gosain et al. (2013)',
#    'Cameron et al. (2012)',
#    'Leighton (1964)',
#    'Whitbread et al. (2017)',
#    'Bai et al. (2021)',
#    'Ramunno et al. (2024)',
#    'Athalathil et al. (2024)',
#    'Yeates et al. (2023)',
#    'Snodgrass & Ulrich (1990)',
#    'Schrijver & Title (2001)',
#    'Hickmann et al. (2015)',
#    'Upton & Hathaway (2013)',
#    'Kutsenko (2021)',
#    'Hale & Nicholson (1925)',
#    'Joy et al. (1919)',
#    'Jiang et al. (2014)',
#    'Pal et al. (2023)'],
#   'approach_used': ['Deep learning-based prediction using Pix2PixCC architecture',
#    'Comparison with conventional SFT and persistent models',
#    'Evaluation using RMSE, FSIM, and pixel-to-pixel correlation coefficient',
#    'Iterative prediction for multiple solar rotations',
#    'Synthetic data validation for differential rotation and meridional flow'],
#   'methodology': 'The study employs a deep learning model based on the Pix2PixCC architecture, incorporating a U-Net generator, a discriminator, and an inspector. The model is trained on synoptic maps from SDO/HMI, SOHO/MDI, and NSO/GONG, covering solar cycles 23, 24, and the ascending phase of cycle 25. Data preprocessing includes interpolation to a uniform grid, augmentation by longitudinal shifting, and padding for spherical representation. The model is evaluated using metrics such as RMSE, FSIM, and pixel-to-pixel correlation coefficient, and it is compared against a persistent model and a conventional SFT model. The AI model demonstrates improved performance in capturing solar phenomena like differential rotation and meridional flow, and it is further validated using synthetic data.',
#   'metrics': ['RMSE', 'FSIM', 'Pixel-to-pixel CC (10x10 binning)'],
#   'limitations': ['Inability to predict newly emerging active regions during a solar rotation',
#    'Dependence on historical data for predictive accuracy',
#    'Challenges in predicting extreme space weather events'],
#   'reproducibility': 4,
#   'strengths': "The AI-based SFT model demonstrates strong predictive capabilities for solar magnetic field evolution over a solar rotation, outperforming traditional models in key metrics. It effectively captures large-scale solar phenomena such as differential rotation and meridional flow, and its iterative approach allows for multi-rotation predictions. The model's robustness is further validated through synthetic data testing, confirming its reliability in simulating solar surface flux transport.",
#   'weaknesses': "The model struggles to predict the emergence of new active regions, which limits its accuracy during periods of high solar activity. Its performance is highly dependent on the quality and continuity of historical data, and it may not fully capture extreme space weather events. Additionally, the model's reliance on past data may introduce biases if the training data does not adequately represent all solar conditions.",
#   'metrics_list': [{'RMSE': 17.8},
#    {'FSIM': 0.46},
#    {'Pixel-to-pixel CC (10x10 binning)': 0.71}],
#   'scores': [17.8, 0.46, 0.71]}]

# %%
from langchain_tavily import TavilySearch

# %%
search_tool = TavilySearch(
    max_results=15,
)

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                                                title        author  \
# 0  Generation of Modern Satellite Data from Galil...    Lee et al.
# 1  Visual Explanation of a Deep Learning Solar Fl...     Yi et al.
# 2  Improved AI-generated Solar Farside Magnetogra...  Jeong et al.
# 3  Construction of global IGS-3D electron density...     Ji et al.
# 4  Generation of He I 1083 nm Images from SDO AIA...  (Son) et al.
#
#                             id  \
# 0     10.3847/1538-4357/abd498
# 1     10.3847/2041-8213/abeb70
# 2     10.3847/2041-8213/ac9116
# 3  10.1016/j.jastp.2024.106370
# 4     10.3847/1538-4357/ac11ae
#
#                                                 data  \
# 0  [Mount Wilson Observatory (MWO) sunspot drawin...
# 1  [Solar and Heliospheric Observatory (SOHO)/Mic...
# 2  [SDO/AIA EUV images (304, 193, 171 Å), SDO/HMI...
# 3  [International Global Navigation Satellite Sys...
# 4  [SDO/AIA 19.3 nm images, SDO/AIA 30.4 nm image...
#
#                                    code_link  \
# 0                              None provided
# 1                              None provided
# 2  https://github.com/JeongHyunJin/Pix2PixCC
# 3                              None provided
# 4                              None provided
#
#                                        packages_used  \
# 0                  [NumPy, Keras, TensorFlow, SunPy]
# 1                       [PyTorch, NumPy, Matplotlib]
# 2  [PyTorch, NumPy, Matplotlib, SciPy, Astropy, S...
# 3                                          [PyTorch]
# 4                                   [Sunpy, AIAPrep]
#
#                                                 task  \
# 0  Generation of modern satellite-like magnetogra...
# 1                             Solar flare prediction
# 2               Solar farside magnetogram generation
# 3  Global 3-D ionospheric electron density distri...
# 4  Generation of He I 1083 nm images from SDO/AIA...
#
#                                       field  \
# 0                             Solar Physics
# 1                              Solar flares
# 2                             Solar Physics
# 3                       Ionospheric Physics
# 4  Solar Chromosphere and Transition Region
#
#                                             keywords  \
# 0  deep learning, generative adversarial networks...
# 1  deep learning, solar flare prediction, CNN, Gr...
# 2  solar magnetograms, deep learning, Pix2Pix, GA...
# 3  deep learning, ionospheric electron density pr...
# 4  deep learning, image-to-image translation, pix...
#
#                                             abstract  ...  \
# 0  This study uses deep learning to generate mode...  ...
# 1  This study presents a visual explanation of a ...  ...
# 2  The paper presents an improved deep-learning m...  ...
# 3  This study presents a deep learning-based meth...  ...
# 4  The study presents a deep learning method (pix...  ...
#
#                                        approach_used  \
# 0  [Image-to-image translation using pix2pix (cGA...
# 1  [CNN-based flare prediction, Attribution metho...
# 2  [Deep learning-based image-to-image translatio...
# 3  [Inversion method to derive electron density p...
# 4  [Image-to-image translation using pix2pixHD, C...
#
#                                          methodology  \
# 0  The study employs a pix2pix model, a type of c...
# 1  The study involves training a CNN model on ful...
# 2  The study introduces the Pix2PixCC model, an e...
# 3  The study employs a deep learning approach usi...
# 4  The study uses the pix2pixHD model, a deep lea...
#
#                                              metrics  \
# 0  [Correlation Coefficient (CC) for TUMF (Magnet...
# 1  [True Skill Statistics (TSS), Accuracy (ACC), ...
# 2  [pixel-to-pixel CC (full disk), pixel-to-pixel...
# 3  [RMSE (log m^-3) - Jicamarca, RMSE (log m^-3) ...
# 4  [CC (Model I), RMSE (Model I), CC (Model II), ...
#
#                                          limitations reproducibility  \
# 0  [The model struggles to reproduce detailed str...               4
# 1  [The model's performance may be affected by th...               3
# 2  [Physical quantities based on pixel-to-pixel d...               4
# 3  [The IRI model's limitations at low latitudes ...               3
# 4  [Differences in filament absorption mechanisms...               4
#
#                                            strengths  \
# 0  The study demonstrates a novel application of ...
# 1  The study provides a novel approach to interpr...
# 2  The Pix2PixCC model significantly improves the...
# 3  The IGS-3D Ne model demonstrates improved accu...
# 4  The study successfully demonstrates the use of...
#
#                                           weaknesses  \
# 0  The model's reliance on sunspot drawings limit...
# 1  The reliance on JPG format magnetograms may in...
# 2  The model's reliance on historical frontside d...
# 3  The model's performance is constrained by the ...
# 4  The study has some limitations, including diff...
#
#                                         metrics_list  \
# 0  [{'Correlation Coefficient (CC) for TUMF (Magn...
# 1  [{'True Skill Statistics (TSS)': 0.65}, {'Accu...
# 2  [{'pixel-to-pixel CC (full disk)': 0.88}, {'pi...
# 3  [{'RMSE (log m^-3) - Jicamarca': 0.37}, {'RMSE...
# 4  [{'CC (Model I)': 0.83}, {'RMSE (Model I)': 11...
#
#                                               scores reuse_potential
# 0  [0.82, 0.74, 0.75, 0.56, 0.65, 0.67, 0.7, 0.76...             NaN
# 1                           [0.65, 0.83, 0.65, 0.61]             NaN
# 2  [0.88, 0.91, 0.7, 0.99, 0.94, 0.94, 0.9, 0.94,...             NaN
# 3                                 [0.37, 0.22, 0.34]             NaN
# 4             [0.83, 11.28, 0.86, 10.15, 0.88, 9.49]             NaN
#
# [5 rows x 26 columns]

# %%
ids = list(df['id'])
tasks = list(df['task'])
fields = list(df['field'])
tasks_set = set(tasks)
fields_set = set(fields)

# %%
query_list = list(map(lambda field: f"{field} deep learning artificial intelligence machine learning cnn\n\nExclude papers with the following DOI/arXiv IDS: {list(df['id'][df['field'] == field])}.", fields_set))

# %%
query_results = list(map(lambda query: search_tool.invoke({'query': query, 'include_domains': ['scholar.google.com', 'arxiv.org']}), query_list))

# %%
query_results
# Out:
# [{'query': "Solar Corona and Inner Heliosphere deep learning artificial intelligence machine learning cnn\n\nExclude papers with the following DOI/arXiv IDS: ['10.3847/1538-4357/acc722'].",
#   'follow_up_questions': None,
#   'answer': None,
#   'images': [],
#   'results': [{'url': 'https://arxiv.org/abs/1902.09673',
#     'title': 'Predicting the Structure of the Solar Corona and Inner Heliosphere ...',
#     'content': "To aid in mission planning, and in anticipation of the unprecedented measurements to be returned, in late October, we developed a three-dimensional magnetohydrodynamic (MHD) solution for the solar corona and inner heliosphere, driven by the then available observations of the Sun's photospheric magnetic field.",
#     'score': 0.3964893,
#     'raw_content': None}],
#   'response_time': 11.56,
#   'request_id': '003a4bd8-a3e8-423d-b711-733c359f6247'},
#  {'query': "Solar Physics deep learning artificial intelligence machine learning cnn\n\nExclude papers with the following DOI/arXiv IDS: ['10.3847/1538-4357/abd498', '10.3847/2041-8213/ac9116', 'arXiv:2502.00001', '10.1038/s41550-019-0715-9', '10.3847/2041-8213/ab96a9', '10.3847/1538-4357/ad32f9', '10.3847/2041-8213/ab77fc', '10.3847/2041-8213/ab9dae', '10.3847/2041-8213/ab4a8c', '10.3847/1538-4357/ad3295'].",
#   'follow_up_questions': None,
#   'answer': None,
#   'images': [],
#   'results': [{'url': 'https://arxiv.org/html/2306.15308',
#     'title': 'Machine learning in solar physics',
#     'content': 'The application of machine learning in solar physics has the potential to greatly enhance our understanding of the complex processes that take place in the atmosphere of the Sun. By using techniques such as deep learning, we are now in the position to analyze large amounts of data from solar observations and identify patterns and trends that may not have been apparent using traditional methods',
#     'score': 0.7180613,
#     'raw_content': None},
#    {'url': 'https://ar5iv.labs.arxiv.org/html/2306.15308',
#     'title': '[2306.15308] Machine learning in solar physics',
#     'content': 'The application of machine learning in solar physics has the potential to greatly enhance our understanding of the complex processes that take place in the atmosphere of the Sun. By using techniques such as deep learni…',
#     'score': 0.6538572,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/abs/2306.15308',
#     'title': '[2306.15308] Machine learning in solar physics - arXiv.org',
#     'content': '> astro-ph > arXiv:2306.15308 **arXiv:2306.15308** (astro-ph) View a PDF of the paper titled Machine learning in solar physics, by A. > Abstract:The application of machine learning in solar physics has the potential to greatly enhance our understanding of the complex processes that take place in the atmosphere of the Sun. By using techniques such as deep learning, we are now in the position to analyze large amounts of data from solar observations and identify patterns and trends that may not have been apparent using traditional methods. |  | (or  arXiv:2306.15308v1 [astro-ph.SR] for this version) | View a PDF of the paper titled Machine learning in solar physics, by A. ## BibTeX formatted citation # Bibliographic and Citation Tools',
#     'score': 0.56517935,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/abs/2204.03710',
#     'title': 'Predicting Solar Flares Using CNN and LSTM on Two Solar Cycles of ...',
#     'content': 'Using line-of-sight magnetograms and parameters of active regions in two data products covering Solar Cycle 23 and 24, we train and evaluate two deep learning algorithms -- CNN and LSTM -- and their stacking ensembles. The decisions of CNN are explained using visual attribution methods. We have the following three main findings.',
#     'score': 0.49714416,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/pdf/2508.16543',
#     'title': 'Explainable AI in Deep Learning-Based Prediction of Solar Storms',
#     'content': 'Interpretable machine learning, or explainable artificial in-telligence (XAI), has recently drawn much attention in the AI field as researchers and practitioners seek to pro-vide more transparency to their models. Miller (2019) de-fined the interpretability of a model as the degree to which an observer can understand the cause of a decision.',
#     'score': 0.43165663,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/abs/1909.05459',
#     'title': '[1909.05459] Application of Convolutional Neural Networks for Stellar ...',
#     'content': 'We examine various machine and deep learning algorithms like Artificial Neural Networks (ANN), Random Forest (RF), and Convolutional Neural Network (CNN) to classify stellar spectra using the Jacoby Atlas, ELODIE and MILES spectral libraries as training samples.',
#     'score': 0.42907107,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/abs/2108.09114',
#     'title': 'CNN-Based Deep Learning in Solar Wind Forecasting',
#     'content': 'Image 2: arxiv logo>astro-ph> arXiv:2108.09114  **arXiv:2108.09114** (astro-ph)  View a PDF of the paper titled CNN-Based Deep Learning in Solar Wind Forecasting, by Hemapriya Raju and 1 other authors (or arXiv:2108.09114v1 [astro-ph.SR] for this version) View a PDF of the paper titled CNN-Based Deep Learning in Solar Wind Forecasting, by Hemapriya Raju and 1 other authors - [x] Bibliographic Explorer Toggle  - [x] Connected Papers Toggle  - [x] Litmaps Toggle  - [x] alphaXiv Toggle  - [x] Links to Code Toggle  - [x] DagsHub Toggle  - [x] GotitPub Toggle  - [x] Huggingface Toggle  - [x] Links to Code Toggle  - [x] ScienceCast Toggle  - [x] Replicate Toggle  - [x] Spaces Toggle  - [x] Spaces Toggle  - [x] Core recommender toggle  - [x] IArxiv recommender toggle ',
#     'score': 0.40330887,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/abs/1912.02934',
#     'title': 'Surveying the reach and maturity of machine learning and artificial ...',
#     'content': 'This review surveys contemporary, published literature on machine learning and artificial intelligence in astronomy and astrophysics. Applications span seven main categories of activity: classification, regression, clustering, forecasting, generation, discovery, and the development of new scientific insight.',
#     'score': 0.39873472,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/abs/2505.03385',
#     'title': 'Solar Flare Forecast: A Comparative Analysis of Machine Learning ...',
#     'content': 'The insights of this study enhance future research by optimizing dimensionality reduction techniques and informing model selection for astrophysical tasks. By integrating this newly acquired knowledge into future research, more accurate space weather forecasting systems can be developed, along with a deeper understanding of solar physics.',
#     'score': 0.37038535,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/html/2409.04850v1',
#     'title': 'Deep Computer Vision for Solar Physics Big Data: Opportunities and ...',
#     'content': 'To address this issue, physics-informed computer vision is crucial in solar physics research because it allows for the integration of established physical laws and domain-specific knowledge directly into deep computer vision models.',
#     'score': 0.32569262,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/html/2407.04283v1',
#     'title': 'A Physics-Informed Machine Learning Approach utilizing Multiband ...',
#     'content': 'Abstract Solar irradiance is fundamental data crucial for analyses related to weather and climate. High-precision estimation models are necessary to create areal data for solar irradiance. In this study, we developed a novel estimation model by utilizing machine learning and multiband data from meteorological satellite observations.',
#     'score': 0.32498527,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/abs/2409.04850',
#     'title': '[2409.04850] Deep Computer Vision for Solar Physics Big Data ...',
#     'content': 'With recent missions such as advanced space-based observatories like the Solar Dynamics Observatory (SDO) and Parker Solar Probe, and ground-based telescopes like the Daniel K. Inouye Solar Telescope (DKIST), the volume, velocity, and variety of data have made solar physics enter a transformative era as solar physics big data (SPBD). With the recent advancement of deep computer vision, there',
#     'score': 0.32277194,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/abs/2408.12476',
#     'title': 'Predicting Solar Energy Generation with Machine Learning based on AQI ...',
#     'content': 'Title:Predicting Solar Energy Generation with Machine Learning based on AQI and Weather Features View a PDF of the paper titled Predicting Solar Energy Generation with Machine Learning based on AQI and Weather Features, by Arjun Shah and 3 other authors We explore the influence of the Air Quality Index and weather features on solar energy generation, employing advanced Machine Learning and Deep Learning techniques. View a PDF of the paper titled Predicting Solar Energy Generation with Machine Learning based on AQI and Weather Features, by Arjun Shah and 3 other authors - [x] Bibliographic Explorer Toggle  - [x] Connected Papers Toggle  - [x] Links to Code Toggle  - [x] Links to Code Toggle  - [x] Core recommender toggle  - [x] IArxiv recommender toggle ',
#     'score': 0.29565728,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/abs/2411.08843',
#     'title': '[2411.08843] Data-driven Surface Solar Irradiance Estimation using ...',
#     'content': 'Accurate surface solar irradiance (SSI) forecasting is essential for optimizing renewable energy systems, particularly in the context of long-term energy planning on a global scale. This paper presents a pioneering approach to solar radiation forecasting that leverages recent advancements in numerical weather prediction (NWP) and data-driven machine learning weather models. These advances',
#     'score': 0.2895178,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/abs/2309.04558',
#     'title': 'Towards Interpretable Solar Flare Prediction with Attention-based Deep ...',
#     'content': 'We gratefully acknowledge support from the Simons Foundation, member institutions, and all contributors. > cs > arXiv:2309.04558 **arXiv:2309.04558** (cs) View a PDF of the paper titled Towards Interpretable Solar Flare Prediction with Attention-based Deep Neural Networks, by Chetraj Pandey and 3 other authors > Abstract:Solar flare prediction is a central problem in space weather forecasting and recent developments in machine learning and deep learning accelerated the adoption of complex models for data-driven solar flare forecasting. |  | (or  arXiv:2309.04558v1 [cs.LG] for this version) | View a PDF of the paper titled Towards Interpretable Solar Flare Prediction with Attention-based Deep Neural Networks, by Chetraj Pandey and 3 other authors Current browse context: Change to browse by: * Google Scholar * Semantic Scholar # Bibliographic and Citation Tools * Institution',
#     'score': 0.25285003,
#     'raw_content': None}],
#   'response_time': 11.21,
#   'request_id': '6ccf6bf7-8e45-4023-a774-188b6e9ec469'},
#  {'query': "Space weather, solar wind deep learning artificial intelligence machine learning cnn\n\nExclude papers with the following DOI/arXiv IDS: ['10.3847/1538-4357/ace04e'].",
#   'follow_up_questions': None,
#   'answer': None,
#   'images': [],
#   'results': [{'url': 'https://arxiv.org/html/2405.02545v1',
#     'title': 'Prediction of Space Weather Events through Analysis ...',
#     'content': 'This study aims to leverage machine learning techniques to predict instances of space weather (solar flares, coronal mass ejections, geomagnetic storms), based on active region magnetograms of the Sun. This was done through the use of the NASA DONKI service to determine when these solar events occur, then using data from the NASA Solar Dynamics Observatory to compile a dataset that includes magnetograms of active regions of the Sun 24 hours before the events. With strong performance in the solar flare and GMS classes, the model shows promising results in the field of space weather prediction. We find that the proposed model is capable of accurately predicting instances of solar flares and geomagnetic storms, while it requires further testing and data aggregation in order to more accurately predict instances of coronal mass ejections.',
#     'score': 0.5003668,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/html/2410.10841v1',
#     'title': 'AI Foundation Model for Heliophysics: Applications, Design ...',
#     'content': 'In [32] , CNN based deep learning model has been used for solar wind forecasting. Additionally, [33] developed a DNN using SDO/AIA 193 Å images to obtain',
#     'score': 0.48908922,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/html/2501.14684v1',
#     'title': '1 Introduction',
#     'content': 'This work highlights in one shot the notable potential of AI in revolutionizing space weather forecasting when the prediction task involves the',
#     'score': 0.48557588,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/html/2508.06892v1',
#     'title': 'Large Model Driven Solar Activity AI Forecaster',
#     'content': 'In the case of the super solar storm in May 2024, AI tools [68] also indicate the potential to identify solar situations and predict events: classify the morphological evolution of active regions through Vision Transformer (ViT), predict strong flares (M-class based on CNN-LSTM video deep learning, and issue a one-hour advance warning of geomagnetic storms through the LSTM model based on in-situ data. Space weather forecasting operational agencies, through the research-to-operation (R2O) approach, have integrated some research-oriented methods such as solar feature recognition, active region magnetic field characteristic calculation, and flare prediction modeling into analysis and forecasting tools.',
#     'score': 0.44594026,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/html/2508.14107v1',
#     'title': 'SuryaBench: Benchmark Dataset for Advancing Machine ...',
#     'content': 'By establishing a unified, standardized data collection, this dataset aims to facilitate benchmarking, enhance reproducibility, and accelerate the development of AI-driven models for critical space weather prediction tasks, bridging gaps between solar physics, machine learning, and operational forecasting. To provide a comprehensive and reusable testing environment and facilitate synergistic research, SuryaBench offers standardized application benchmark datasets (hereafter called Datasets, for brevity) for the following six key tasks in heliophysics: (1) solar flare prediction, (2) active region segmentation, (3) active region emergence prediction, (4) coronal magnetic field extrapolation, (5) solar irradiance, and (6) solar wind forecasting. Formally, given solar observation data (such as AIA and HMI multi-channel solar imaging data) represented by at observation time , the task is to predict the scalar solar wind speed at time , where days:',
#     'score': 0.42276734,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/pdf/2203.01184',
#     'title': 'A few-shot learning approach to classify Solar WInd ...',
#     'content': 'by H Lamdouar · 2022 — Applying machine learning (ML) to solar wind magnetic field data allows us to quickly and accurately classify these small-scale structures to',
#     'score': 0.35985944,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/pdf/2304.01234',
#     'title': 'arXiv:2304.01234v1 [astro-ph.SR] 3 Apr 2023',
#     'content': 'by R Lin · 2023 · Cited by 1 — A model based on convolutional neural network is trained to predict the solar wind speed upstream of the Earth. This model uses four potential',
#     'score': 0.3375097,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/html/2507.10893v1',
#     'title': 'Modernizing CNN-based Weather Forecast Model towards ...',
#     'content': 'Therefore, we introduce the Korea Advanced Institute of Science and Technology (KAIST) AI model for Atmosphere (KAI-) model, an ultralight CNN-based model designed for global daily weather forecasting, requiring only around 7 million parameters, and just 12 hours of training on a single NVIDIA L40s GPU. Moreover, the use of band convolutions is particularly advantageous for datasets like ERA5, as their large receptive fields enable the efficient capture of extensive atmospheric phenomena, thereby enhancing the network’s ability to model complex, large-scale patterns Yu et\xa0al. We evaluate the forecast performance of KAI- in comparison with two state-of-the-art (SOTA) deep learning-based models, Pangu-Weather and GraphCast, both available through the WeatherBench-2 benchmark Rasp et\xa0al.',
#     'score': 0.12331308,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/html/2407.08259v1',
#     'title': 'Wind Power Assessment based on Super-Resolution and ...',
#     'content': 'In this paper, we compare the performance of various deep learning models on two distinct tasks: super-resolution, where we map artificially',
#     'score': 0.11382585,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/pdf/2501.15731',
#     'title': 'Renewable Energy Prediction: A Comparative Study of ...',
#     'content': 'Abstract. The increasing focus on predicting renewable energy production aligns with advancements in deep learning (DL). The inherent variability of',
#     'score': 0.051144414,
#     'raw_content': None}],
#   'response_time': 2.06,
#   'request_id': 'b23aa4bf-ca4c-4faf-931f-119091f6608a'},
#  "No search results found for 'Solar Physics / Space Weather deep learning artificial intelligence machine learning cnn\n\nExclude papers with the following DOI/arXiv IDS: ['10.3847/1538-4357/ad19a6'].'. Suggestions: Remove include_domains argument, Try a general search using 'general' topic. Try modifying your search parameters with one of these approaches.",
#  {'query': "Space Weather, Solar Wind deep learning artificial intelligence machine learning cnn\n\nExclude papers with the following DOI/arXiv IDS: ['10.3847/1538-4357/ad4d5d'].",
#   'follow_up_questions': None,
#   'answer': None,
#   'images': [],
#   'results': [{'title': 'arXiv [2108.09114] CNN-Based Deep Learning in Solar Wind Forecasting',
#     'url': 'https://arxiv.org/abs/2108.09114',
#     'content': 'Image 2: arxiv logo>astro-ph> arXiv:2108.09114  **arXiv:2108.09114** (astro-ph)  View a PDF of the paper titled CNN-Based Deep Learning in Solar Wind Forecasting, by Hemapriya Raju and 1 other authors (or arXiv:2108.09114v1 [astro-ph.SR] for this version) View a PDF of the paper titled CNN-Based Deep Learning in Solar Wind Forecasting, by Hemapriya Raju and 1 other authors - [x] Bibliographic Explorer Toggle  - [x] Connected Papers Toggle  - [x] Litmaps Toggle  - [x] alphaXiv Toggle  - [x] Links to Code Toggle  - [x] DagsHub Toggle  - [x] GotitPub Toggle  - [x] Huggingface Toggle  - [x] Links to Code Toggle  - [x] ScienceCast Toggle  - [x] Replicate Toggle  - [x] Spaces Toggle  - [x] Spaces Toggle  - [x] Core recommender toggle  - [x] IArxiv recommender toggle ',
#     'score': 0.45856747,
#     'raw_content': None},
#    {'title': 'arXiv [1811.02323] Machine Learning Approach for Solar Wind Categorization',
#     'url': 'https://arxiv.org/abs/1811.02323',
#     'content': 'August 23, 2019 - Solar wind classification is conducive to understand the physical processes ongoing at the Sun and solar wind evolution in the interplanetary space , and furthermore, it is helpful for early warning of space weather events. With rapid developments in the field of artificial intelligence , machine',
#     'score': 0.434102,
#     'raw_content': None},
#    {'title': 'arXiv [2006.05825] Solar wind prediction using deep learning',
#     'url': 'https://arxiv.org/abs/2006.05825',
#     'content': 'Image 2: arxiv logo>astro-ph> arXiv:2006.05825  View a PDF of the paper titled Solar wind prediction using deep learning, by Vishal Upendran and 3 other authors View a PDF of the paper titled Solar wind prediction using deep learning, by Vishal Upendran and 3 other authors - [x] Bibliographic Explorer Toggle  - [x] Connected Papers Toggle  - [x] Litmaps Toggle  - [x] scite.ai Toggle  - [x] alphaXiv Toggle  - [x] Links to Code Toggle  - [x] DagsHub Toggle  - [x] GotitPub Toggle  - [x] Huggingface Toggle  - [x] Links to Code Toggle  - [x] ScienceCast Toggle  - [x] Replicate Toggle  - [x] Spaces Toggle  - [x] Spaces Toggle  - [x] Core recommender toggle  - [x] IArxiv recommender toggle ',
#     'score': 0.38650924,
#     'raw_content': None},
#    {'title': 'arXiv Prediction of Space Weather Events through Analysis of Active Region Magnetograms using Convolutional Neural Network',
#     'url': 'https://arxiv.org/html/2405.02545v1',
#     'content': 'This study aims to leverage machine learning techniques to predict instances of space weather (solar flares, coronal mass ejections, geomagnetic storms), based on active region magnetograms of the Sun. This was done through the use of the NASA DONKI service to determine when these solar events occur, then using data from the NASA Solar Dynamics Observatory to compile a dataset that includes magnetograms of active regions of the Sun 24 hours before the events. With strong performance in the solar flare and GMS classes, the model shows promising results in the field of space weather prediction. We find that the proposed model is capable of accurately predicting instances of solar flares and geomagnetic storms, while it requires further testing and data aggregation in order to more accurately predict instances of coronal mass ejections.',
#     'score': 0.33502495,
#     'raw_content': None},
#    {'title': 'Artificial Intelligence Could Have Predicted All Space ... Prediction of Space Weather Events through Analysis of Active ... [2501.06907] Deep Learning and Foundation Models for Weather ... Deep Learning for Space Weather Prediction: Bridging the Gap ... [2212.13328] Deep Learning for Space Weather Prediction ... SuryaBench: Benchmark Dataset for Advancing Machine Learning ... Deep Learning and Foundation Models for Weather Prediction: A ...',
#     'url': 'https://arxiv.org/abs/2501.14684',
#     'content': "We gratefully acknowledge support from the Simons Foundation, member institutions, and all contributors. > astro-ph > arXiv:2501.14684 **arXiv:2501.14684** (astro-ph) View a PDF of the paper titled Artificial Intelligence Could Have Predicted All Space Weather Events Associated with the May 2024 Superstorm, by Sabrina Guastavino and 3 other authors |  | (or  arXiv:2501.14684v1 [astro-ph.SR] for this version) | Current browse context: astro-ph.SR Change to browse by: astro-ph physics physics.space-ph * Google Scholar * Semantic Scholar # Bibliographic and Citation Tools Papers with Code *(What is Papers with Code?)* * Institution Have an idea for a project that will add value for arXiv's community? **Learn more about arXivLabs**.",
#     'score': 0.2963288,
#     'raw_content': None},
#    {'title': 'arXiv Forecasting High-Speed Solar Wind Streams from Solar Images',
#     'url': 'https://arxiv.org/html/2410.05068',
#     'content': 'January 6, 2025 - By testing the model on almost ... modern artificial intelligence models. We show that the size and location of coronal holes as well as past solar wind speed measurements are the most important features for these predictions. Additionally, we demonstrate that our model can be used for an operational real-time forecast on recent data. Space weather effects in',
#     'score': 0.29098135,
#     'raw_content': None},
#    {'title': 'arXiv Advancing Solar Flare Prediction using Deep Learning with Active Region Patches',
#     'url': 'https://arxiv.org/html/2406.11054v1',
#     'content': 'Our contributions can be summarized as follows: (i) we propose a novel methodology for preprocessing magnetograms of AR patches, focusing on preserving shape-based parameters while maximizing the total unsigned flux (USFLUX) [3] at the instance level, (ii) we showcase that our models are capable of predicting flares across the entire solar disk, including often overlooked near-limb regions, improving the comprehensiveness of AR-based solar flare prediction models, and (iii) through rigorous experimentation, our models demonstrate superior performance compared to existing approaches, significantly contributing to ongoing efforts aimed at enhancing space weather forecasting capabilities. Furthermore, a CNN-based flare forecasting model trained with AR patches (resized to 100100 pixels) extracted from LoS magnetograms within 30∘ of the solar longitude to predict C-, M-, and X-class flares was presented in [13].',
#     'score': 0.26160243,
#     'raw_content': None},
#    {'title': 'Prediction of Space Weather Events through Analysis of Active ...',
#     'url': 'https://arxiv.org/pdf/2405.02545',
#     'content': 'This study aims to leverage machine learning techniques to predict instances of space weather (solar flares, coronal mass ejections, geomagnetic storms), based on active region magnetograms of the Sun.',
#     'score': 0.23678127,
#     'raw_content': None},
#    {'title': 'arXiv Explainable AI in Deep Learning-Based Prediction of Solar Storms',
#     'url': 'https://arxiv.org/html/2508.16543',
#     'content': '1 month ago - The Helioseismic and Magnetic Imager (HMI) vector magnetic field pipeline: SHARPs - space - weather HMI active region patches. Solar Physics 289(11):3549–3578. Feldhaus and Carande (2021) Feldhaus, C., and Carande, W. 2021. Explainable artificial intelligence for solar flare prediction.',
#     'score': 0.2023017,
#     'raw_content': None},
#    {'title': 'arXiv Large Model Driven Solar Activity AI Forecaster: A Scalable Dual Data-Model Framework',
#     'url': 'https://arxiv.org/html/2508.06892',
#     'content': 'August 9, 2025 - Meanwhile, machine learning has ... neural networks (CNNs) and long-short-term memory (LSTM) models have demonstrably surpassed traditional statistical approaches [54, 41, 55, 44, 56, 57, 58, 59, 60]. Recently, large artificial intelligence (AI) models have gradually',
#     'score': 0.18546021,
#     'raw_content': None},
#    {'title': 'Deep Learning for Space Weather Prediction: Bridging the Gap ...',
#     'url': 'https://arxiv.org/pdf/2212.13328',
#     'content': 'Further, we believe that high performance deep learning is about to transform the way we think about the development of space weather models, providing a bridge between “physics based” and “data driven” modeling that will enable significant progress in both areas (see Figure 1). 2. Deep learning for space weather prediction.',
#     'score': 0.1819457,
#     'raw_content': None},
#    {'title': '[2212.13328] Deep Learning for Space Weather Prediction ...',
#     'url': 'https://arxiv.org/abs/2212.13328',
#     'content': 'Dec 27, 2022 · Traditionally, data analysis and theory have been viewed as separate disciplines, each feeding into fundamentally different types of models. Modern deep learning technology is beginning to unify these two disciplines and will produce a new class of predictively powerful space weather models that combine the physical insights gained by data and theory. We call on NASA to invest in the research',
#     'score': 0.17233925,
#     'raw_content': None},
#    {'title': 'arXiv Sky image-based solar forecasting using deep learning ...',
#     'url': 'https://arxiv.org/pdf/2211.02108',
#     'content': 'arXiv is working with academic researchers to investigate ways to improve the service for our users. This requires a rich dataset to better inform the research. Users who wish to contribute to the future of arXiv may opt in to allow arXiv to use their reading data for research purposes.',
#     'score': 0.1634591,
#     'raw_content': None},
#    {'title': 'arXiv [2508.16543] Explainable AI in Deep Learning-Based Prediction of Solar Storms',
#     'url': 'https://arxiv.org/abs/2508.16543',
#     'content': "We gratefully acknowledge support from the Simons Foundation, member institutions, and all contributors. > cs > arXiv:2508.16543 | Subjects: | Machine Learning (cs.LG) | | Cite as: | arXiv:2508.16543 [cs.LG] | |  | (or  arXiv:2508.16543v1 [cs.LG] for this version) | |  |  arXiv-issued DOI via DataCite | Current browse context: cs.LG Change to browse by: * Google Scholar * Semantic Scholar Hugging Face *(What is Huggingface?)* Hugging Face Spaces *(What is Spaces?)* * Institution arXivLabs is a framework that allows collaborators to develop and share new arXiv features directly on our website. arXiv is committed to these values and only works with partners that adhere to them. Have an idea for a project that will add value for arXiv's community?",
#     'score': 0.15792774,
#     'raw_content': None},
#    {'title': '[2501.06907] Deep Learning and Foundation Models for Weather ...',
#     'url': 'https://arxiv.org/abs/2501.06907',
#     'content': "arxiv logo arXiv logo Cornell University Logo | Subjects: | Machine Learning (cs.LG) | | Cite as: | arXiv:2501.06907 [cs.LG] | |  | (or  arXiv:2501.06907v1 [cs.LG] for this version) | |  |  Focus to learn more  arXiv-issued DOI via DataCite | ### References & Citations # Bibliographic and Citation Tools # Recommenders and Search Tools arXivLabs is a framework that allows collaborators to develop and share new arXiv features directly on our website. Both individuals and organizations that work with arXivLabs have embraced and accepted our values of openness, community, excellence, and user data privacy. arXiv is committed to these values and only works with partners that adhere to them. Have an idea for a project that will add value for arXiv's community? **Learn more about arXivLabs**. arXiv Operational Status   ",
#     'score': 0.15568112,
#     'raw_content': None}],
#   'response_time': 4.64,
#   'request_id': '0165231e-5820-4e49-9680-e33cc47a4791'},
#  {'query': "Solar extreme ultraviolet (EUV) emission deep learning artificial intelligence machine learning cnn\n\nExclude papers with the following DOI/arXiv IDS: ['10.3847/1538-4357/aca42a'].",
#   'follow_up_questions': None,
#   'answer': None,
#   'images': [],
#   'results': [{'url': 'https://arxiv.org/html/2508.14112v1',
#     'title': 'Surya: Foundation Model for Heliophysics',
#     'content': 'A deep learning virtual instrument for monitoring extreme uv solar spectral irradiance. Science Advances, 5(10):eaaw6548, 2019. doi: 10.1126',
#     'score': 0.24474682,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/html/2508.18867v1',
#     'title': 'Multi-Instrument Observations and Tracking of a Coronal ...',
#     'content': 'A deep learning virtual instrument for monitoring extreme UV solar spectral irradiance. Science Advances, 5(10), eaaw6548. 10.1126/sciadv.aaw6548. Telloni',
#     'score': 0.19682656,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/html/2508.14107v1',
#     'title': 'SuryaBench: Benchmark Dataset for Advancing Machine ...',
#     'content': 'By establishing a unified, standardized data collection, this dataset aims to facilitate benchmarking, enhance reproducibility, and accelerate the development of AI-driven models for critical space weather prediction tasks, bridging gaps between solar physics, machine learning, and operational forecasting. To provide a comprehensive and reusable testing environment and facilitate synergistic research, SuryaBench offers standardized application benchmark datasets (hereafter called Datasets, for brevity) for the following six key tasks in heliophysics: (1) solar flare prediction, (2) active region segmentation, (3) active region emergence prediction, (4) coronal magnetic field extrapolation, (5) solar irradiance, and (6) solar wind forecasting. Formally, given solar observation data (such as AIA and HMI multi-channel solar imaging data) represented by at observation time , the task is to predict the scalar solar wind speed at time , where days:',
#     'score': 0.041871805,
#     'raw_content': None},
#    {'url': 'https://arxiv.org/html/2402.08797v1',
#     'title': 'Computing Power and the Governance of Artificial ...',
#     'content': 'Computing power, or "compute," is crucial for the development and deployment of artificial intelligence (AI) capabilities.',
#     'score': 0.03874536,
#     'raw_content': None}],
#   'response_time': 2.72,
#   'request_id': 'e9244d27-f5fa-4375-8e5f-a92104342c8d'},
#  {'query': "Solar Chromosphere deep learning artificial intelligence machine learning cnn\n\nExclude papers with the following DOI/arXiv IDS: ['10.3847/1538-4357/ac9c6e'].",
#   'follow_up_questions': None,
#   'answer': None,
#   'images': [],
#   'results': [{'title': 'Google Scholar',
#     'url': 'https://scholar.google.com/',
#     'content': 'Google Scholar Loading... The system can\'t perform the operation now. [](javascript:void(0)) Advanced search **Find articles** with **all** of the words  with **at least one** of the words  **without** the words  where my words occur  anywhere in the article  in the title of the article  Return articles **authored** by  e.g., _"PJ Hayes"_ or _McCarthy_ Return articles **published** in  e.g., _J Biol Chem_ or _Nature_ Return articles **dated** between  e.g., _1996_ [](javascript:void(0)) Saved to My library Done Remove article [](javascript:void(0))[](https://scholar.google.com/schhp?hl=en&as_sdt=0,41) [My profile](https://scholar.google.com/citations?hl=en)[My library](https://scholar.google.com/scholar?scilib=1&hl=en&as_sdt=0,41)[Alerts](https://scholar.google.com/scholar_alerts?view_op=list_alerts&hl=en)[Metrics](https://scholar.google.com/citations?view_op=metrics_intro&hl=en) [Advanced search](javascript:void(0)) [Settings](https://scholar.google.com/scholar_settings?sciifh=1&hl=en&as_sdt=0,41) [Sign in](https://accounts.google.com/Login?hl=en&continue=https://scholar.google.com/) [](javascript:void(0))[](https://scholar.google.com/schhp?hl=en&as_sdt=0,41) [My profile](https://scholar.google.com/citations?hl=en)[My library](https://scholar.google.com/scholar?scilib=1&hl=en&as_sdt=0,41) ![Image 1](https://scholar.google.com/intl/en/scholar/images/1x/scholar_logo_64dp.png) [Sign in](https://accounts.google.com/Login?hl=en&continue=https://scholar.google.com/) [](javascript:void(0)) Articles Case law  Federal courts South Carolina courts [Select courts...](https://scholar.google.com/scholar_courts?hl=en&as_sdt=0,41) [EN](javascript:void(0)) [English](javascript:void(0))[Español](https://scholar.google.com/scholar_setlang?scisig=AAZF9b8AAAAAaMu1wxGVCKhXm8GjGTTClW0VST4&as_sdt=0,41&hl=es)[Català](https://scholar.google.com/scholar_setlang?scisig=AAZF9b8AAAAAaMu1wxGVCKhXm8GjGTTClW0VST4&as_sdt=0,41&hl=ca)[Čeština](https://scholar.google.com/scholar_setlang?scisig=AAZF9b8AAAAAaMu1wxGVCKhXm8GjGTTClW0VST4&as_sdt=0,41&hl=cs)[Dansk](https://scholar.google.com/scholar_setlang?scisig=AAZF9b8AAAAAaMu1wxGVCKhXm8GjGTTClW0VST4&as_sdt=0,41&hl=da)[Deutsch](https://scholar.google.com/scholar_setlang?scisig=AAZF9b8AAAAAaMu1wxGVCKhXm8GjGTTClW0VST4&as_sdt=0,41&hl=de)[Filipino](https://scholar.google.com/scholar_setlang?scisig=AAZF9b8AAAAAaMu1wxGVCKhXm8GjGTTClW0VST4&as_sdt=0,41&hl=tl)[Français](https://scholar.google.com/scholar_setlang?scisig=AAZF9b8AAAAAaMu1wxGVCKhXm8GjGTTClW0VST4&as_sdt=0,41&hl=fr) [Hrvatski](https://scholar.google.com/scholar_setlang?scisig=AAZF9b8AAAAAaMu1wxGVCKhXm8GjGTTClW0VST4&as_sdt=0,41&hl=hr)[Indonesia](https://scholar.google.com/scholar_setlang?scisig=AAZF9b8AAAAAaMu1wxGVCKhXm8GjGTTClW0VST4&as_sdt=0,41&hl=id)[Italiano](https://scholar.google.com/scholar_setlang?scisig=AAZF9b8AAAAAaMu1wxGVCKhXm8GjGTTClW0VST4&as_sdt=0,41&hl=it)[Latviešu](https://scholar.google.com/scholar_setlang?scisig=AAZF9b8AAAAAaMu1wxGVCKhXm8GjGTTClW0VST4&as_sdt=0,41&hl=lv)[Lietuvių](https://scholar.google.com/scholar_setlang?scisig=AAZF9b8AAAAAaMu1wxGVCKhXm8GjGTTClW0VST4&as_sdt=0,41&hl=lt)[Magyar](https://scholar.google.com/scholar_setlang?scisig=AAZF9b8AAAAAaMu1wxGVCKhXm8GjGTTClW0VST4&as_sdt=0,41&hl=hu)[Nederlands](https://scholar.google.com/scholar_setlang?scisig=AAZF9b8AAAAAaMu1wxGVCKhXm8GjGTTClW0VST4&as_sdt=0,41&hl=nl)[Norsk](https://scholar.google.com/scholar_setlang?scisig=AAZF9b8AAAAAaMu1wxGVCKhXm8GjGTTClW0VST4&as_sdt=0,41&hl=no) [Polski](https://scholar.google.com/scholar_setlang?scisig=AAZF9b8AAAAAaMu1wxGVCKhXm8GjGTTClW0VST4&as_sdt=0,41&hl=pl)[Português (Brasil)](https://scholar.google.com/scholar_setlang?scisig=AAZF9b8AAAAAaMu1wxGVCKhXm8GjGTTClW0VST4&as_sdt=0,41&hl=pt-BR)[Português (Portugal)](https://scholar.google.com/scholar_setlang?scisig=AAZF9b8AAAAAaMu1wxGVCKhXm8GjGTTClW0VST4&as_sdt=0,41&hl=pt-PT)[Română](https://scholar.google.com/scholar_setlang?scisig=AAZF9b8AAAAAaMu1wxGVCKhXm8GjGTTClW0VST4&as_sdt=0,41&hl=ro)[Sloven ...
#     'score': 0.3351555,
#     'raw_content': None},
#    {'title': 'arXiv Computational Astrophysics, Data Science & AI/ML in Astronomy: A Perspective from Indian Community',
#     'url': 'https://arxiv.org/html/2501.03876v1',
#     'content': 'January 7, 2025 - 1Department of Physics, Indian Institute of Science, Bangalore 560012, India \\affilTwo2DAASE, Indian Institute of Technology, Indore, Madhya Pradesh, 453552, India \\affilThree3NCRA, Tata Institute of Fundamental Research, Ganeshkhind, Pune 411007, India \\affilFour4IISER Mohali, Knowledge City,',
#     'score': 0.3012392,
#     'raw_content': None},
#    {'title': 'Coupled Ocean-Atmosphere Dynamics in a Machine Learning Earth ... Zhenyuan Dong - Google Scholar [2410.14963] Deep Learning for Weather Forecasting: A CNN ... Christopher Olah - Google Scholar',
#     'url': 'https://arxiv.org/abs/2406.08632',
#     'content': 'View a PDF of the paper titled Coupled Ocean-Atmosphere Dynamics in a Machine Learning Earth System Model, by Chenggong Wang and 7 other authors We present the Ocean-linked-atmosphere (Ola) model, a high-resolution (0.25°) Artificial Intelligence/ Machine Learning (AI/ML) coupled earth-system model which separately models the ocean and atmosphere dynamics using an autoregressive Spherical Fourier Neural Operator architecture, with a view towards enabling fast, accurate, large ensemble forecasts on the seasonal timescale. Subjects:Atmospheric and Oceanic Physics (physics.ao-ph); Machine Learning (cs.LG) View a PDF of the paper titled Coupled Ocean-Atmosphere Dynamics in a Machine Learning Earth System Model, by Chenggong Wang and 7 other authors - [x] Connected Papers Toggle  - [x] Links to Code Toggle  - [x] Links to Code Toggle ',
#     'score': 0.17104766,
#     'raw_content': None},
#    {'title': '[2410.14963] Deep Learning for Weather Forecasting: A CNN ...',
#     'url': 'https://arxiv.org/abs/2410.14963',
#     'content': '[2410.14963] Deep Learning for Weather Forecasting: A CNN-LSTM Hybrid Model for Predicting Historical Temperature Data Title:Deep Learning for Weather Forecasting: A CNN-LSTM Hybrid Model for Predicting Historical Temperature Data View a PDF of the paper titled Deep Learning for Weather Forecasting: A CNN-LSTM Hybrid Model for Predicting Historical Temperature Data, by Yuhao Gong and 3 other authors View a PDF of the paper titled Deep Learning for Weather Forecasting: A CNN-LSTM Hybrid Model for Predicting Historical Temperature Data, by Yuhao Gong and 3 other authors - [x] Bibliographic Explorer Toggle  - [x] Connected Papers Toggle  - [x] alphaXiv Toggle  - [x] Links to Code Toggle  - [x] Links to Code Toggle  - [x] Core recommender toggle  - [x] IArxiv recommender toggle ',
#     'score': 0.107315995,
#     'raw_content': None},
#    {'title': 'Danfeng Hong (洪丹枫) - Google Scholar',
#     'url': 'https://scholar.google.com/citations?user=n7gL0_IAAAAJ&hl=en',
#     'content': 'Southeast University - Cited by 23,820 - Artificial intelligence - Multimodality - Foundation model - Hyperspectral imaging - Earth observation',
#     'score': 0.08279386,
#     'raw_content': None},
#    {'title': 'Zhenyuan Dong - Google Scholar',
#     'url': 'https://scholar.google.com/citations?user=bwqFwY4AAAAJ&hl=en',
#     'content': 'Purdue University, PhD Student at ECE Department - Cited by 14 - Computer Vision - Machine Learning - Representation Learning - Generative Models',
#     'score': 0.047678076,
#     'raw_content': None},
#    {'title': 'Do machine learning climate models work in changing climate ...',
#     'url': 'https://arxiv.org/pdf/2509.12147',
#     'content': 'While machine learning (ML) models have shown promise in providing precise, high-speed climate predictions, their ability to generalize under distribution shifts re-mains a significant limitation that has been underexplored in climate contexts.',
#     'score': 0.038789026,
#     'raw_content': None},
#    {'title': 'Christopher Olah - Google Scholar',
#     'url': 'https://scholar.google.com/citations?user=6dskOSUAAAAJ&hl=en',
#     'content': 'This "Cited by" count includes citations to the following articles in Scholar. The second column has the \\"recent\\" version of this metric which is the number of new citations in the last 5 years to all publications.") | 96774 | 73871 | The second column has the \\"recent\\" version of this metric which is the number of publications that have received at least 10 new citations in the last 5 years.") | 68 | 64 | | Conditional image synthesis with auxiliary classifier gans A Odena, C Olah, J Shlens International conference on machine learning, 2642-2651, 2017 | 4638 | 2017 | | Zoom in: An introduction to circuits C Olah, N Cammarata, L Schubert, G Goh, M Petrov, S Carter Distill 5 (3), e00024.',
#     'score': 0.03616903,
#     'raw_content': None}],
#   'response_time': 6.41,
#   'request_id': 'd3cca8b2-cd34-4e58-ba2e-0d547e871e10'},
#  {'query': "Solar Flares deep learning artificial intelligence machine learning cnn\n\nExclude papers with the following DOI/arXiv IDS: ['10.3847/2041-8213/ab738e'].",
#   'follow_up_questions': None,
#   'answer': None,
#   'images': [],
#   'results': [{'title': 'arXiv [2204.03710] Predicting Solar Flares Using CNN and LSTM on Two Solar Cycles of Active Region Data',
#     'url': 'https://arxiv.org/abs/2204.03710',
#     'content': '# Title:Predicting Solar Flares Using CNN and LSTM on Two Solar Cycles of Active Region Data View a PDF of the paper titled Predicting Solar Flares Using CNN and LSTM on Two Solar Cycles of Active Region Data, by Zeyu Sun and 7 other authors Using line-of-sight magnetograms and parameters of active regions in two data products covering Solar Cycle 23 and 24, we train and evaluate two deep learning algorithms -- CNN and LSTM -- and their stacking ensembles. View a PDF of the paper titled Predicting Solar Flares Using CNN and LSTM on Two Solar Cycles of Active Region Data, by Zeyu Sun and 7 other authors ## BibTeX formatted citation',
#     'score': 0.5404151,
#     'raw_content': None},
#    {'title': 'arXiv An Interpretable Machine Learning Approach to Understanding the Relationships between Solar Flares and Source Active Regions',
#     'url': 'https://arxiv.org/html/2502.15066v1',
#     'content': 'February 20, 2025 - Solar flares are defined as outbursts on the surface of the Sun. They occur when energy accumulated in magnetic fields enclosing solar active regions (ARs) is abruptly expelled. Solar flares and associated coronal mass ejections are sources of space weather that adversely impact devices at',
#     'score': 0.498902,
#     'raw_content': None},
#    {'title': 'arXiv Advancing Solar Flare Prediction using Deep Learning with Active Region Patches',
#     'url': 'https://arxiv.org/html/2406.11054v1',
#     'content': 'Our contributions can be summarized as follows: (i) we propose a novel methodology for preprocessing magnetograms of AR patches, focusing on preserving shape-based parameters while maximizing the total unsigned flux (USFLUX) [3] at the instance level, (ii) we showcase that our models are capable of predicting flares across the entire solar disk, including often overlooked near-limb regions, improving the comprehensiveness of AR-based solar flare prediction models, and (iii) through rigorous experimentation, our models demonstrate superior performance compared to existing approaches, significantly contributing to ongoing efforts aimed at enhancing space weather forecasting capabilities. Furthermore, a CNN-based flare forecasting model trained with AR patches (resized to 100100 pixels) extracted from LoS magnetograms within 30∘ of the solar longitude to predict C-, M-, and X-class flares was presented in [13].',
#     'score': 0.44709876,
#     'raw_content': None},
#    {'title': 'arXiv [2405.16080] A Deep Learning Approach to Operational Flare Forecasting',
#     'url': 'https://arxiv.org/abs/2405.16080',
#     'content': 'May 25, 2024 - Solar flares are explosions on the Sun. They happen when energy stored in magnetic fields around solar active regions (ARs) is suddenly released. In this paper, we present a transformer-based framework, named SolarFlareNet, for predicting whether an AR would produce a gamma-class flare within',
#     'score': 0.4229103,
#     'raw_content': None},
#    {'title': 'arXiv [2411.18070] Large Scale Evaluation of Deep Learning-based Explainable Solar Flare Forecasting Models with Attribution-based Proximity Analysis',
#     'url': 'https://arxiv.org/abs/2411.18070',
#     'content': 'November 27, 2024 - Accurate and reliable predictions of solar flares are essential due to their potentially significant impact on Earth and space-based infrastructure. Although deep learning models have shown notable predictive capabilities in this domain, current evaluations often focus on accuracy while neglecting',
#     'score': 0.41364354,
#     'raw_content': None},
#    {'title': 'arXiv [2309.04558] Towards Interpretable Solar Flare Prediction with Attention-based Deep Neural Networks',
#     'url': 'https://arxiv.org/abs/2309.04558',
#     'content': 'We gratefully acknowledge support from the Simons Foundation, member institutions, and all contributors. > cs > arXiv:2309.04558 **arXiv:2309.04558** (cs) View a PDF of the paper titled Towards Interpretable Solar Flare Prediction with Attention-based Deep Neural Networks, by Chetraj Pandey and 3 other authors > Abstract:Solar flare prediction is a central problem in space weather forecasting and recent developments in machine learning and deep learning accelerated the adoption of complex models for data-driven solar flare forecasting. |  | (or  arXiv:2309.04558v1 [cs.LG] for this version) | View a PDF of the paper titled Towards Interpretable Solar Flare Prediction with Attention-based Deep Neural Networks, by Chetraj Pandey and 3 other authors Current browse context: Change to browse by: * Google Scholar * Semantic Scholar # Bibliographic and Citation Tools * Institution',
#     'score': 0.3936886,
#     'raw_content': None},
#    {'title': 'arXiv [1912.00502] Predicting solar flares with machine learning: investigating solar cycle dependence',
#     'url': 'https://arxiv.org/abs/1912.00502',
#     'content': 'January 23, 2020 - A deep learning network, Long-Short Term Memory (LSTM) network, is used in this work to predict whether the maximum flare class an active region (AR) will produce in the next 24 hours is class $Γ$. We considered $Γ$ are $\\ge M$, $\\ge C$ and any flare class.',
#     'score': 0.37607357,
#     'raw_content': None},
#    {'title': 'arXiv Deep Space Weather Model: Long-Range Solar Flare Prediction from Multi-Wavelength Images',
#     'url': 'https://arxiv.org/html/2508.07847v1',
#     'content': 'August 11, 2025 - Accurate, reliable solar flare prediction is crucial for mitigating potential disruptions to critical infrastructure, while predicting solar flares remains a significant challenge. Existing methods based on heuristic physical features often lack representation learning from solar images.',
#     'score': 0.37154752,
#     'raw_content': None},
#    {'title': 'arXiv [2309.14483] Unveiling the Potential of Deep Learning Models for Solar Flare Prediction in Near-Limb Regions',
#     'url': 'https://arxiv.org/abs/2309.14483',
# ...
#     'content': 'June 19, 2018 - Among the eruptive activity phenomena observed on the Sun, the most technology threatening ones are flares with associated coronal mass ejections (CMEs) and solar energetic particles ( SEPs ). Flares with associated CMEs and SEPs are produced by magnetohydrodynamical processes in magnetically',
#     'score': 0.3962089,
#     'raw_content': None},
#    {'title': 'Segmentation and Tracking of Eruptive Solar Phenomena with ...',
#     'url': 'https://arxiv.org/abs/2509.05623',
#     'content': 'Sep 6, 2025 · Most solar feature detection and tracking algorithms currently in use have restricted applicability and complicated processing chains, while complexity in engineering machine learning (ML) training sets limit the use of data-driven approaches for tracking or solar eruptive related phenomena.',
#     'score': 0.39543822,
#     'raw_content': None},
#    {'title': 'Forecasting and Analysis of Solar Energetic Particle ...',
#     'url': 'https://arxiv.org/pdf/2502.15555',
#     'content': 'Abstract. Solar Energetic Particle ( SEPs ) with energies ranging from tens of keV to a few GeV, are a significant component in the description of the space envi-ronment. In this work, the HESPERIA REleASE product is emphasized, which, based on the Relativistic Electron Alert System for Exploration (REleASE) fore-casting scheme, generates real-time predictions of the proton flux (30-50 MeV) at',
#     'score': 0.39145303,
#     'raw_content': None},
#    {'title': 'MEMPSEP I : Forecasting the Probability of Solar Energetic ...',
#     'url': 'https://arxiv.org/pdf/2309.14570',
#     'content': 'A recent review article by Whitman et al. (2022) provided a comprehensive overview of the large variety of current SEP forecasting models encompassing physics-based, empirical, and machine learning (ML) models and that the outputs may be categorical, binary, prob-abilistic, or deterministic.',
#     'score': 0.3708637,
#     'raw_content': None},
#    {'title': 'Simulation of solar energetic particle events originated from ...',
#     'url': 'https://arxiv.org/html/2411.04095v1',
#     'content': 'Abstract Solar energetic particle (SEP) events are associated with coronal mass ejections (CMEs) and/ or solar flares. SEPs travel through the corona and interplanetary space to reach Earth, posing a radiation hazard to spacecraft and astronauts working in space and the electronics on spacecraft. Due to the distinct magnetic field configuration and solar eruption kinematic properties associated',
#     'score': 0.3369858,
#     'raw_content': None},
#    {'title': 'arXiv [1801.05781] The Propitious Role of Solar Energetic Particles in the Origin of Life',
#     'url': 'https://arxiv.org/abs/1801.05781',
#     'content': 'January 17, 2018 - We carry out 3-D numerical simulations to assess the penetration and bombardment effects of Solar Energetic Particles ( SEPs ), i.e. high-energy particle bursts during large flares and superflares, on ancient and current Mars. We demonstrate that the deposition of SEPs is non-uniform at the planetary',
#     'score': 0.29291928,
#     'raw_content': None},
#    {'title': 'Solar Energetic Particle Time Series Analysis with Python',
#     'url': 'https://arxiv.org/pdf/2210.10432',
#     'content': 'A powerful method to study SEP events is to use multi-spacecraft observations of the same event that are situated at various locations with respect to the source region. This can allow, for example, to disentangle source properties from transport effects. The tools presented in this manuscript, which enable such multi-spacecraft analyses, have been developed within the Solar energetic particle',
#     'score': 0.28280783,
#     'raw_content': None},
#    {'title': 'arXiv Explainable AI in Deep Learning-Based Prediction of Solar Storms',
#     'url': 'https://arxiv.org/html/2508.16543',
#     'content': '1 month ago - A deep learning model is often considered a black-box model, as its internal workings tend to be opaque to the user. Because of the lack of transparency, it is challenging to understand the reasoning behind the model’s predictions. Here, we present an approach to making a deep learning -based',
#     'score': 0.22792482,
#     'raw_content': None},
#    {'title': 'Electrical Engineering and Systems Science',
#     'url': 'https://arxiv.org/list/eess/new',
#     'content': 'We use artificial intelligence ( AI ) and supervisory adaptive control systems to plan and optimize the mission of precise spacecraft formation. Machine learning',
#     'score': 0.040256884,
#     'raw_content': None},
#    {'title': 'Artificial Intelligence',
#     'url': 'https://arxiv.org/list/cs.AI/new',
#     'content': 'This study identifies, appraises and synthesizes published studies on the use of AI for the prognosis of COVID-19. Method: Electronic search was performed using',
#     'score': 0.026377967,
#     'raw_content': None},
#    {'title': 'Computer Vision and Pattern Recognition',
#     'url': 'https://arxiv.org/list/cs.CV/new',
#     'content': 'This study presents a systematic comparison between hybrid quantum-classical neural networks and purely classical models across three benchmark datasets',
#     'score': 0.023368675,
#     'raw_content': None}],
#   'response_time': 5.91,
#   'request_id': '8b81d495-d236-44d2-bc73-22d6a9e7a646'},
#  {'query': "Solar Chromosphere and Transition Region deep learning artificial intelligence machine learning cnn\n\nExclude papers with the following DOI/arXiv IDS: ['10.3847/1538-4357/ac11ae'].",
#   'follow_up_questions': None,
#   'answer': None,
#   'images': [],
#   'results': [{'title': 'arXiv [2506.16194] Solar Transient Recognition Using Deep Learning (STRUDL) for heliospheric imager data',
#     'url': 'https://arxiv.org/abs/2506.16194',
#     'content': 'August 7, 2025 - Coronal Mass Ejections (CMEs) are space weather phenomena capable of causing significant disruptions to both space- and ground-based infrastructure. The timely and accurate detection and prediction of CMEs is a crucial steps towards implementing strategies to minimize the impacts of such events.',
#     'score': 0.4674539,
#     'raw_content': None},
#    {'title': 'arXiv [2306.15308] Machine learning in solar physics',
#     'url': 'https://arxiv.org/abs/2306.15308',
#     'content': '> astro-ph > arXiv:2306.15308 **arXiv:2306.15308** (astro-ph) View a PDF of the paper titled Machine learning in solar physics, by A. > Abstract:The application of machine learning in solar physics has the potential to greatly enhance our understanding of the complex processes that take place in the atmosphere of the Sun. By using techniques such as deep learning, we are now in the position to analyze large amounts of data from solar observations and identify patterns and trends that may not have been apparent using traditional methods. |  | (or  arXiv:2306.15308v1 [astro-ph.SR] for this version) | View a PDF of the paper titled Machine learning in solar physics, by A. ## BibTeX formatted citation # Bibliographic and Citation Tools',
#     'score': 0.43554196,
#     'raw_content': None},
#    {'title': 'arXiv Large Model Driven Solar Activity AI Forecaster: A Scalable Dual Data-Model Framework',
#     'url': 'https://arxiv.org/html/2508.06892',
#     'content': 'August 9, 2025 - These authors contributed equally to this work',
#     'score': 0.37524903,
#     'raw_content': None},
#    {'title': 'arXiv [2204.03710] Predicting Solar Flares Using CNN and LSTM on Two Solar Cycles of Active Region Data',
#     'url': 'https://arxiv.org/abs/2204.03710',
#     'content': '# Title:Predicting Solar Flares Using CNN and LSTM on Two Solar Cycles of Active Region Data View a PDF of the paper titled Predicting Solar Flares Using CNN and LSTM on Two Solar Cycles of Active Region Data, by Zeyu Sun and 7 other authors Using line-of-sight magnetograms and parameters of active regions in two data products covering Solar Cycle 23 and 24, we train and evaluate two deep learning algorithms -- CNN and LSTM -- and their stacking ensembles. View a PDF of the paper titled Predicting Solar Flares Using CNN and LSTM on Two Solar Cycles of Active Region Data, by Zeyu Sun and 7 other authors ## BibTeX formatted citation',
#     'score': 0.3036497,
#     'raw_content': None},
#    {'title': 'arXiv Predicting the Emergence of Solar Active Regions Using Machine Learning',
#     'url': 'https://arxiv.org/html/2402.08890v1',
#     'content': 'Our analysis includes three main steps as presented in Figure\xa01: a) initial data processing, b) preparation of the ML-ready input data and continuum intensity time series to verify results, and c) development and training of an ML-driven model to predict the appearance of active regions using the Long Short-Term Memory (LSTM) method. To address this, we use machine learning to advance the cross-analysis of the local time evolution of the acoustic power for four frequency ranges (2–3, 3–4, 4–5, and 5–6 mHz) and predict a decrease in the mean continuum intensity associated with the appearance of an active region on the solar surface (Figure\xa01, bottom panel).',
#     'score': 0.29443854,
#     'raw_content': None},
#    {'title': 'arXiv An Interpretable Machine Learning Approach to Understanding the Relationships between Solar Flares and Source Active Regions',
#     'url': 'https://arxiv.org/html/2502.15066v1',
#     'content': 'February 20, 2025 - \\BBOQ\\APACrefatitle Predicting Solar Flares Using SDO/HMI Vector Magnetic Data Products and the Random Forest Algorithm Predicting solar flares using SDO/HMI vector magnetic data products and the random forest algorithm.\\BBCQ \\APACjournalVolNumPagesApJ8432104.',
#     'score': 0.2875332,
#     'raw_content': None},
#    {'title': 'arXiv [2508.16543] Explainable AI in Deep Learning-Based Prediction of Solar Storms',
#     'url': 'https://arxiv.org/abs/2508.16543',
#     'content': "We gratefully acknowledge support from the Simons Foundation, member institutions, and all contributors. > cs > arXiv:2508.16543 | Subjects: | Machine Learning (cs.LG) | | Cite as: | arXiv:2508.16543 [cs.LG] | |  | (or  arXiv:2508.16543v1 [cs.LG] for this version) | |  |  arXiv-issued DOI via DataCite | Current browse context: cs.LG Change to browse by: * Google Scholar * Semantic Scholar Hugging Face *(What is Huggingface?)* Hugging Face Spaces *(What is Spaces?)* * Institution arXivLabs is a framework that allows collaborators to develop and share new arXiv features directly on our website. arXiv is committed to these values and only works with partners that adhere to them. Have an idea for a project that will add value for arXiv's community?",
#     'score': 0.28687343,
#     'raw_content': None},
#    {'title': 'arXiv [2410.16116] Multimodal Flare Forecasting with Deep Learning',
#     'url': 'https://arxiv.org/abs/2410.16116',
#     'content': 'October 21, 2024 - Solar flare forecasting mainly relies on photospheric magnetograms and associated physical features to predict forthcoming flares . However, it is believed that flare initiation mechanisms often originate in the chromosphere and the lower corona. In this study, we employ deep learning as a purely',
#     'score': 0.27849758,
#     'raw_content': None},
#    {'title': 'arXiv [2402.08890] Predicting the Emergence of Solar Active Regions Using Machine Learning',
#     'url': 'https://arxiv.org/abs/2402.08890',
#     'content': "We gratefully acknowledge support from the Simons Foundation, member institutions, and all contributors. > astro-ph > arXiv:2402.08890 **arXiv:2402.08890** (astro-ph) | Comments: | 9 pages, 4 figures, IAU Symposium 365 Proceedings | | Subjects: | Solar and Stellar Astrophysics (astro-ph.SR); Machine Learning (cs.LG) | | Cite as: | arXiv:2402.08890 [astro-ph.SR] | |  | (or  arXiv:2402.08890v1 [astro-ph.SR] for this version) | IAU 19 (2023) 311-319 | From: Spiridon Kasapis [view email] **[v1]** Wed, 14 Feb 2024 01:41:50 UTC (2,724 KB) Current browse context: astro-ph.SR Change to browse by: * Google Scholar * Semantic Scholar * Institution arXivLabs is a framework that allows collaborators to develop and share new arXiv features directly on our website. Have an idea for a project that will add value for arXiv's community?",
#     'score': 0.25718442,
#     'raw_content': None},
#    {'title': 'arXiv [2410.21046] Deep Learning the Forecast of Galactic Cosmic-Ray Spectra',
#     'url': 'https://arxiv.org/abs/2410.21046',
#     'content': 'January 10, 2025 - We introduce a novel deep learning framework based on Long Short-Term Memory (LSTM) networks to predict galactic cosmic-ray spectra on a one-day-ahead basis by leveraging historical solar activity data, overcoming limitations inherent in traditional transport models.',
#     'score': 0.24538368,
#     'raw_content': None},
#    {'title': 'arXiv Advancing Solar Flare Prediction using Deep Learning with Active Region Patches',
#     'url': 'https://arxiv.org/html/2406.11054v1',
#     'content': 'Our contributions can be summarized as follows: (i) we propose a novel methodology for preprocessing magnetograms of AR patches, focusing on preserving shape-based parameters while maximizing the total unsigned flux (USFLUX) [3] at the instance level, (ii) we showcase that our models are capable of predicting flares across the entire solar disk, including often overlooked near-limb regions, improving the comprehensiveness of AR-based solar flare prediction models, and (iii) through rigorous experimentation, our models demonstrate superior performance compared to existing approaches, significantly contributing to ongoing efforts aimed at enhancing space weather forecasting capabilities. Furthermore, a CNN-based flare forecasting model trained with AR patches (resized to 100100 pixels) extracted from LoS magnetograms within 30∘ of the solar longitude to predict C-, M-, and X-class flares was presented in [13].',
#     'score': 0.22197445,
#     'raw_content': None},
#    {'title': 'arXiv Explainable AI in Deep Learning-Based Prediction of Solar Storms',
#     'url': 'https://arxiv.org/html/2508.16543',
#     'content': '1 month ago - A deep learning model is often considered a black-box model, as its internal workings tend to be opaque to the user. Because of the lack of transparency, it is challenging to understand the reasoning behind the model’s predictions. Here, we present an approach to making a deep learning -based',
#     'score': 0.22197445,
#     'raw_content': None},
#    {'title': 'arXiv Developing an Automated Detection, Tracking and Analysis Method for Solar Filaments Observed by CHASE via Machine Learning',
#     'url': 'https://arxiv.org/html/2402.14209v1',
#     'content': 'February 22, 2024 - Studies on the dynamics of solar filaments have significant implications for understanding their formation, evolution, and eruption, which are of great importance for space weather warning and forecasting. The Hα𝛼\\alphaitalic_α Imaging Spectrograph (HIS) onboard the recently launched Chinese',
#     'score': 0.19580965,
#     'raw_content': None},
#    {'title': 'arXiv Solar Active Regions Emergence Prediction Using Long Short-Term Memory Networks',
#     'url': 'https://arxiv.org/html/2409.17421v1',
#     'content': 'September 25, 2024 - We developed Long Short-Term Memory (LSTM) models to predict the formation of active regions (ARs) on the solar surface . Using the Doppler shift velocity, the continuum intensity, and the magnetic field observations from the Solar Dynamics Observatory (SDO) Helioseismic and Magnetic Imager',
#     'score': 0.18356468,
#     'raw_content': None},
#    {'title': 'arXiv 1 Introduction',
#     'url': 'https://arxiv.org/html/2410.17816v1',
#     'content': 'October 23, 2024 - A solar active region can significantly disrupt the Sun–Earth space environment, often leading to severe space weather events such as solar flares and coronal mass ejections. As a consequence, the automatic classification of active region groups is the crucial starting point for accurately',
#     'score': 0.17275754,
#     'raw_content': None}],
#   'response_time': 3.28,
#   'request_id': '6dc51899-1f88-484b-a841-99a504793db7'}]

# %%
urls = []
for query in query_results:
    if type(query) != str:
        for result in query['results']:
            urls.append(result['url'])

# %%
urls = list(filter(lambda url: url != 'https://scholar.google.com/', urls))
urls = list(filter(lambda url: 'abs' in url or 'html' in url or 'pdf' in url, urls))

# %%
urls = list(map(lambda url: url.replace('abs', 'pdf'), urls))
urls = list(map(lambda url: url.replace('html', 'pdf'), urls))
urls
# Out:
# ['https://arxiv.org/pdf/1902.09673',
#  'https://arxiv.org/pdf/2306.15308',
#  'https://ar5iv.lpdf.arxiv.org/pdf/2306.15308',
#  'https://arxiv.org/pdf/2306.15308',
#  'https://arxiv.org/pdf/2204.03710',
#  'https://arxiv.org/pdf/2508.16543',
#  'https://arxiv.org/pdf/1909.05459',
#  'https://arxiv.org/pdf/2108.09114',
#  'https://arxiv.org/pdf/1912.02934',
#  'https://arxiv.org/pdf/2505.03385',
#  'https://arxiv.org/pdf/2409.04850v1',
#  'https://arxiv.org/pdf/2407.04283v1',
#  'https://arxiv.org/pdf/2409.04850',
#  'https://arxiv.org/pdf/2408.12476',
#  'https://arxiv.org/pdf/2411.08843',
#  'https://arxiv.org/pdf/2309.04558',
#  'https://arxiv.org/pdf/2405.02545v1',
#  'https://arxiv.org/pdf/2410.10841v1',
#  'https://arxiv.org/pdf/2501.14684v1',
#  'https://arxiv.org/pdf/2508.06892v1',
#  'https://arxiv.org/pdf/2508.14107v1',
#  'https://arxiv.org/pdf/2203.01184',
#  'https://arxiv.org/pdf/2304.01234',
#  'https://arxiv.org/pdf/2507.10893v1',
#  'https://arxiv.org/pdf/2407.08259v1',
#  'https://arxiv.org/pdf/2501.15731',
#  'https://arxiv.org/pdf/2108.09114',
#  'https://arxiv.org/pdf/1811.02323',
#  'https://arxiv.org/pdf/2006.05825',
#  'https://arxiv.org/pdf/2405.02545v1',
#  'https://arxiv.org/pdf/2501.14684',
#  'https://arxiv.org/pdf/2410.05068',
#  'https://arxiv.org/pdf/2406.11054v1',
#  'https://arxiv.org/pdf/2405.02545',
#  'https://arxiv.org/pdf/2508.16543',
#  'https://arxiv.org/pdf/2508.06892',
#  'https://arxiv.org/pdf/2212.13328',
#  'https://arxiv.org/pdf/2212.13328',
#  'https://arxiv.org/pdf/2211.02108',
#  'https://arxiv.org/pdf/2508.16543',
#  'https://arxiv.org/pdf/2501.06907',
#  'https://arxiv.org/pdf/2508.14112v1',
#  'https://arxiv.org/pdf/2508.18867v1',
#  'https://arxiv.org/pdf/2508.14107v1',
#  'https://arxiv.org/pdf/2402.08797v1',
#  'https://arxiv.org/pdf/2501.03876v1',
#  'https://arxiv.org/pdf/2406.08632',
#  'https://arxiv.org/pdf/2410.14963',
#  'https://arxiv.org/pdf/2509.12147',
#  'https://arxiv.org/pdf/2204.03710',
#  'https://arxiv.org/pdf/2502.15066v1',
#  'https://arxiv.org/pdf/2406.11054v1',
#  'https://arxiv.org/pdf/2405.16080',
#  'https://arxiv.org/pdf/2411.18070',
#  'https://arxiv.org/pdf/2309.04558',
#  'https://arxiv.org/pdf/1912.00502',
#  'https://arxiv.org/pdf/2508.07847v1',
#  'https://arxiv.org/pdf/2309.14483',
#  'https://arxiv.org/pdf/2309.14483',
#  'https://arxiv.org/pdf/2202.08776',
#  'https://arxiv.org/pdf/2308.02682',
#  'https://arxiv.org/pdf/1805.03421',
#  'https://arxiv.org/pdf/1411.1405',
#  'https://arxiv.org/pdf/2307.15878',
#  'https://arxiv.org/pdf/2509.05623',
#  'https://arxiv.org/pdf/2410.20843',
#  'https://arxiv.org/pdf/2401.16388v1',
#  'https://arxiv.org/pdf/2211.02108',
#  'https://arxiv.org/pdf/2410.20843',
#  'https://arxiv.org/pdf/2410.20843v1',
#  'https://arxiv.org/pdf/2109.10834',
#  'https://arxiv.org/pdf/2509.05623',
#  'https://arxiv.org/pdf/2109.10834.pdf',
#  'https://arxiv.org/pdf/2108.09114',
#  'https://arxiv.org/pdf/2508.16543',
#  'https://arxiv.org/pdf/2405.09802',
#  'https://arxiv.org/pdf/2406.11054v1',
#  'https://arxiv.org/pdf/2508.16543',
#  'https://arxiv.org/pdf/2309.04558',
#  'https://arxiv.org/pdf/2508.07065',
#  'https://arxiv.org/pdf/2306.15308',
#  'https://arxiv.org/pdf/2508.06892',
#  'https://arxiv.org/pdf/2508.07847v1',
#  'https://arxiv.org/pdf/1911.04008',
#  'https://arxiv.org/pdf/2509.09988',
#  'https://www.arxiv.org/pdf/2409.04850',
#  'https://arxiv.org/pdf/2409.04850',
#  'https://arxiv.org/pdf/2409.04850v1',
#  'https://arxiv.org/pdf/2108.09114',
#  'https://arxiv.org/pdf/2406.11054v1',
#  'https://arxiv.org/pdf/1905.13575',
#  'https://arxiv.org/pdf/2308.14976',
#  'https://arxiv.org/pdf/2408.17430',
#  'https://arxiv.org/pdf/2508.16543',
#  'https://arxiv.org/pdf/2506.16810v2',
#  'https://arxiv.org/pdf/2509.05623v1',
#  'https://arxiv.org/pdf/2503.06144v1',
#  'https://arxiv.org/pdf/2409.00118',
#  'https://arxiv.org/pdf/2409.00118v1',
#  'https://arxiv.org/pdf/2503.22790',
#  'https://arxiv.org/pdf/2305.17473',
#  'https://arxiv.org/pdf/2509.02661',
#  'https://arxiv.org/pdf/2409.04850v1',
#  'https://arxiv.org/pdf/2109.09499',
#  'https://arxiv.org/pdf/2503.19160',
#  'https://arxiv.org/pdf/2509.13571',
#  'https://arxiv.org/pdf/2509.04663',
#  'https://arxiv.org/pdf/2509.10579',
#  'https://www.arxiv.org/pdf/2502.08555',
#  'https://arxiv.org/pdf/2406.11054v1',
#  'https://arxiv.org/pdf/2212.13328',
#  'https://arxiv.org/pdf/2404.15284v1',
#  'https://arxiv.org/pdf/2006.12224',
#  'https://arxiv.org/pdf/2501.14684v1',
#  'https://arxiv.org/pdf/2509.00631',
#  'https://arxiv.org/pdf/2409.00118v1',
#  'https://arxiv.org/pdf/2508.16543',
#  'https://arxiv.org/pdf/2501.14684',
#  'https://arxiv.org/pdf/2409.00118',
#  'https://arxiv.org/pdf/2501.06907v1',
#  'https://arxiv.org/pdf/2109.09499',
#  'https://arxiv.org/pdf/1810.13273',
#  'https://arxiv.org/pdf/2403.18864v1',
#  'https://arxiv.org/pdf/2502.15555',
#  'https://arxiv.org/pdf/2203.14393',
#  'https://arxiv.org/pdf/1806.07117',
#  'https://arxiv.org/pdf/2509.05623',
#  'https://arxiv.org/pdf/2502.15555',
#  'https://arxiv.org/pdf/2309.14570',
#  'https://arxiv.org/pdf/2411.04095v1',
#  'https://arxiv.org/pdf/1801.05781',
#  'https://arxiv.org/pdf/2210.10432',
#  'https://arxiv.org/pdf/2508.16543',
#  'https://arxiv.org/pdf/2506.16194',
#  'https://arxiv.org/pdf/2306.15308',
#  'https://arxiv.org/pdf/2508.06892',
#  'https://arxiv.org/pdf/2204.03710',
#  'https://arxiv.org/pdf/2402.08890v1',
#  'https://arxiv.org/pdf/2502.15066v1',
#  'https://arxiv.org/pdf/2508.16543',
#  'https://arxiv.org/pdf/2410.16116',
#  'https://arxiv.org/pdf/2402.08890',
#  'https://arxiv.org/pdf/2410.21046',
#  'https://arxiv.org/pdf/2406.11054v1',
#  'https://arxiv.org/pdf/2508.16543',
#  'https://arxiv.org/pdf/2402.14209v1',
#  'https://arxiv.org/pdf/2409.17421v1',
#  'https://arxiv.org/pdf/2410.17816v1']

# %%
import requests

# %%
dirs = '../queried_papers'

os.makedirs(dirs, exist_ok=True)

# %%
def download_pdf(url):
    filename = url.split('/')[-1] + '.pdf'
    file_dir = os.path.join(dirs, filename)
    response = requests.get(url)

    if response.status_code == 200 and not os.path.exists(file_dir):
        with open(file_dir, 'wb') as f:
            f.write(response.content)

# %%
indices = []
for i, url in enumerate(urls):
    try:
        download_pdf(url)
    except:
        indices.append(i)

# %%
indices
# Out:
# [2]

# %%
download_pdf(urls[2].replace('ar5iv.lpdf.', ''))

# %%
queried_papers_list = []

for file in os.listdir(dirs):
    queried_papers_list.append(os.path.join(dirs, file))

# %%
queried_papers = []
indices = []
for i, file in enumerate(queried_papers_list):
    try:
        pdf = extract_pdf(file)

        content = []

        for page in pdf.pages:
            content.append(page.markdown)

        papers.append({
            'file_name': file,
            'content': content
        })
    except: indices.append(i)

# %%
titles = list(map(lambda paper: paper['file_name'], papers))

# %%
papers_df = pd.DataFrame(papers)

# %%
papers_df.head()
# Out:
#                                            file_name  \
# 0  Generation of Modern Satellite Data from Galil...
# 1  Visual Explanation of a Deep Learning Solar Fl...
# 2  Improved AI-generated Solar Farside Magnetogra...
# 3  Construction of global IGS-3D electron density...
# 4  Generation of He i 1083 nm Images from SDO AIA...
#
#                                              content
# 0  # Generation of Modern Satellite Data from Gal...
# 1  # Visual Explanation of a Deep Learning Solar ...
# 2  # Improved AI-generated Solar Farside Magnetog...
# 3  # Construction of global IGS-3D electron densi...
# 4  # Generation of He I 1083 nm Images from SDO A...

# %%
papers_df = papers_df.drop_duplicates(subset='file_name')

# %%
papers_df.to_csv('listup_v1.csv', index=False)

# %%
papers_df = pd.read_csv('../listup_v1.csv')

# %%
papers_df
# Out:
# 143

# %%
paper92 = extract_pdf('../papers/2202.08776.pdf')

# %%
content = []

for page in paper92.pages:
    content.append(page.markdown)

# %%
missing_paper = {
            'file_name': '2202.08776.pdf',
            'content': '\n'.join(content)
        }

# %%
papers_df = pd.concat([papers_df, pd.DataFrame(missing_paper, index=[0])])

# %%
papers_df = papers_df.reset_index()
papers_df = papers_df.drop(columns='index')

# %%
papers_df.to_csv('../listup_v1.csv', index=False)
